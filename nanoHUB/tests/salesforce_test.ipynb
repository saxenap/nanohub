# %%
from nanoHUB.infrastructure.salesforce.contact import (
    SalesforceFromEnvironment,
    ContactMapper,
    ContactFactory
)
import pprint
# Out:
# nanoHUB - Serving Students, Researchers & Instructors

# %%
factory = SalesforceFromEnvironment('test')

# %%
contact_mapper = ContactMapper(factory.create_new(), ContactFactory())
print(contact_mapper)
# Out:
# <nanoHUB.infrastructure.salesforce.contact.ContactMapper object at 0x7f4a18212a60>

# %%
contact1 = contact_mapper.find_by_username('1vineetkumarsingh')
print(contact1['attributes'])
print(contact1['Id'])
print(contact1['AccountId'])
print(contact1['MiddleName'])
pprint.pprint(contact1, sort_dicts=False)
# Out:
# OrderedDict([('attributes',
#               OrderedDict([('type', 'Contact'),
#                            ('url',
#                             '/services/data/v52.0/sobjects/Contact/0035w000034JszLAAS')])),
#              ('Id', '0035w000034JszLAAS'),
#              ('IsDeleted', False),
#              ('MasterRecordId', None),
#              ('AccountId', '0015w000029SDA3AAO'),
#              ('LastName', 'singh'),
#              ('FirstName', 'vineet'),
#              ('Salutation', None),
#              ('MiddleName', 'kumar'),
#              ('Name', 'vineet kumar singh'),
#              ('OtherStreet', None),
#              ('OtherCity', None),
#              ('OtherState', None),
#              ('OtherPostalCode', None),
#              ('OtherCountry', None),
#              ('OtherLatitude', None),
#              ('OtherLongitude', None),
#              ('OtherGeocodeAccuracy', None),
#              ('OtherAddress', None),
#              ('MailingStreet', None),
#              ('MailingCity', None),
#              ('MailingState', None),
#              ('MailingPostalCode', None),
#              ('MailingCountry', None),
#              ('MailingLatitude', None),
#              ('MailingLongitude', None),
#              ('MailingGeocodeAccuracy', None),
#              ('MailingAddress', None),
#              ('Phone', None),
#              ('Fax', None),
#              ('MobilePhone', None),
#              ('HomePhone', None),
#              ('OtherPhone', None),
#              ('AssistantPhone', None),
#              ('ReportsToId', None),
#              ('Email', '1vineetkumarsingh@gmail.com'),
#              ('Title', None),
#              ('Department', None),
#              ('AssistantName', None),
#              ('LeadSource', 'Advertisement'),
#              ('Birthdate', None),
#              ('Description', None),
#              ('OwnerId', '0055w00000ArpYvAAJ'),
#              ('HasOptedOutOfEmail', True),
#              ('CreatedDate', '2020-04-28T05:52:17.000+0000'),
#              ('CreatedById', '0055w00000ArpYvAAJ'),
#              ('LastModifiedDate', '2022-05-24T15:05:03.000+0000'),
#              ('LastModifiedById', '0055w00000DM5bOAAT'),
#              ('SystemModstamp', '2022-05-24T15:05:03.000+0000'),
#              ('LastActivityDate', None),
#              ('LastCURequestDate', None),
#              ('LastCUUpdateDate', None),
#              ('LastViewedDate', '2022-05-25T19:55:09.000+0000'),
#              ('LastReferencedDate', '2022-05-25T19:55:09.000+0000'),
#              ('EmailBouncedReason', None),
#              ('EmailBouncedDate', None),
#              ('IsEmailBounced', False),
#              ('PhotoUrl', '/services/images/photo/0035w000034JszLAAS'),
#              ('Jigsaw', None),
#              ('JigsawContactId', None),
#              ('IndividualId', None),
#              ('Type__c', None),
#              ('nanoHUB_user_ID__c', 109690.0),
#              ('nanoHUB_username__c', '1vineetkumarsingh'),
#              ('Organization_Type__c', 'universityfaculty'),
#              ('nanoHUB_registration_date__c', '2014-10-03'),
#              ('nanoHUB_last_active_date__c', '2022-05-20'),
#              ('hed__AlternateEmail__c', '1vineetkumarsingh@gmail.com'),
#              ('hed__Chosen_Full_Name__c', None),
#              ('hed__Citizenship__c', None),
#              ('hed__Country_of_Origin__c', None),
#              ('hed__Current_Address__c', None),
#              ('hed__Deceased__c', False),
#              ('hed__Do_Not_Contact__c', False),
#              ('hed__Dual_Citizenship__c', None),
#              ('hed__Ethnicity__c', None),
#              ('hed__Exclude_from_Household_Formal_Greeting__c', False),
#              ('hed__Exclude_from_Household_Informal_Greeting__c', False),
#              ('hed__Exclude_from_Household_Name__c', False),
#              ('hed__FERPA__c', False),
#              ('hed__Financial_Aid_Applicant__c', False),
#              ('hed__Gender__c', 'Male'),
#              ('hed__HIPAA_Detail__c', None),
#              ('hed__HIPAA__c', False),
#              ('hed__Military_Background__c', None),
#              ('hed__Military_Service__c', False),
#              ('hed__Naming_Exclusions__c', None),
#              ('hed__PreferredPhone__c', None),
#              ('hed__Preferred_Email__c', 'Alternate Email'),
#              ('hed__Primary_Address_Type__c', None),
#              ('hed__Primary_Household__c', None),
#              ('hed__Primary_Language__c', None),
#              ('hed__Primary_Organization__c', None),
#              ('hed__Race__c', 'Asian'),
#              ('hed__Religion__c', None),
#              ('hed__Secondary_Address_Type__c', None),
#              ('hed__Social_Security_Number__c', None),
#              ('hed__UniversityEmail__c', None),
#              ('hed__WorkEmail__c', None),
#              ('hed__WorkPhone__c', None),
#              ('hed__Work_Address__c', None),
#              ('hed__is_Address_Override__c', False),
#              ('nanoHUB_account_BLOCKED__c', False),
#              ('CS_Qualtrics2022__c',
#               'https://purdue.ca1.qualtrics.com/jfe/form/SV_38EJP7inYQdfLZY?Q_DL=SALV06IxhmADweI_38EJP7inYQdfLZY_MLRP_eYh26QAaXlt3LLw&Q_CHL=gl'),
#              ('et4ae5__HasOptedOutOfMobile__c', False),
#              ('et4ae5__Mobile_Country_Code__c', None),
#              ('Detailed_user_timeline_to_Tableau__c',
#               'https://tableauqa.itap.purdue.edu/views/profile/ProfileTimeline?Id%20Email=1vineetkumarsingh@gmail.com&:iframeSizedToWindow=true&:embed=y&:showAppBanner=false&:display_count=no&:showVizHome=no#6'),
#              ('nanoHUB_user_page__c', 'https://nanohub.org/members/109690'),
#              ('ORCID__c', None),
#              ('Organization__c',
#               'ddu gorakhpur university, gorakhpur, u.p., india'),
#              ('Organization_Conflict__c', False),
#              ('Total_simulation_runs__c', 137.0),
#              ('Total_citations__c', 0.0),
#              ('Total_clusters__c', 0.0),
#              ('Total_of_tools_used__c', 20.0),
#              ('Active_duration__c', 2786.0),
#              ('Disciplines__c', None),
#              ('Total_tool_contributions__c', 0.0),
#              ('NCN_staff__c', False),
#              ('NCN_funded__c', False),
#              ('NCN_Affiliated__c', False),
#              ('NCN_Notes__c', None),
#              ('ORCID_sf__c', None),
#              ('Linkedin_Bio__c', None),
#              ('Misc_URLs__c', None),
#              ('Organization_email_derived__c', None),
#              ('Organization_Overwrite__c', None),
#              ('Organization_citation_derived__c', None),
#              ('Organization_cluster_derived__c', None),
#              ('Organization_composite__c', None),
#              ('Associated_Contact__c', None),
#              ('Association_comment__c', None),
#              ('Research_ID__c', None),
#              ('Google_Scholar_ID__c', None),
#              ('SCOPUS_ID__c', None),
#              ('ResearchGate_ID__c', None),
#              ('Contact_Type__c', None),
#              ('Secondary_Account_of__c', None),
#              ('rh2__Currency_Test__c', None),
#              ('rh2__Describe__c', None),
#              ('rh2__Formula_Test__c', 0.0),
#              ('rh2__Integer_Test__c', None),
#              ('Lead_ID__c', None),
#              ('Engagement__c', None),
#              ('Qualtrics_Survey__c',
#               'https://purdue.ca1.qualtrics.com/jfe/form/SV_cPgeTM5vvNfnUEd?Q_DL=kLiVJ5bRqOH8bwO_cPgeTM5vvNfnUEd_MLRP_8rdr3ecpb0owsw5&Q_CHL=gl'),
#              ('wiki_contributions__c', 0.0),
#              ('Faculty_Identification__c', None),
#              ('Verified_Phone_Number__c', None),
#              ('Twitter_profile__c', None),
#              ('Facebook_profile__c', None),
#              ('Lead_Venue__c', None),
#              ('Twitter_Influencer__c', False),
#              ('Facebook_Influencer__c', False),
#              ('LinkedIn_Influencer__c', False),
#              ('And_More_Contributions__c', 0.0),
#              ('contributed_tool_usage__c', 0.0),
#              ('contributed_andmore_usage__c', 0.0),
#              ('Email_Bounced__c', False),
#              ('personalizedcommunication__c', True),
#              ('updatesnews__c', True),
#              ('nh_use_survey_link__c',
#               'https://nanohub.org/reply/pages/2?code=71f6069ec45083e512b3c6749bfce3783208cfc31dcd2f6347233571069a9988'),
#              ('new_preferences_survey_url__c',
#               'https://nanohub.org/reply/email-subscriptions?code=e4802355931521d45e901aa098f3ce19ba19adcc89d8fdf9d84854ce4a1cc33a'),
#              ('contributor__c', False),
#              ('paper_contributions__c', 0.0),
#              ('presentations_contributions__c', 0.0),
#              ('wiki_usage__c', 0.0),
#              ('Home_Page__c', None),
#              ('Reason__c', 'Required for class'),
#              ('howdidyouhear__c', None),
#              ('Purpose__c', None),
#              ('Disability__c', None),
#              ('Hispanic__c', None),
#              ('Native_Tribe__c', None),
#              ('Lead_Contact_Date__c', None),
#              ('Venue__c',
#               '2022 Customer Satisfaction Survey recipient;CustSatSurvey2022'),
#              ('Lead_Time__c', None),
#              ('nHPro_qualtrics_survey__c',
#               'https://purdue.ca1.qualtrics.com/jfe/form/SV_79dZf0asgXHY0v3?Q_DL=wuPLDHrd0B0BlX1_79dZf0asgXHY0v3_MLRP_bqs1vH2WBS338tT&Q_CHL=gl'),
#              ('Champion__c', None),
#              ('Research_ID_sf__c', None),
#              ('Google_Scholar_ID_sf__c', None),
#              ('sim_lifetimes__c', 1990.0),
#              ('earliest_sim__c', '2016-12-06'),
#              ('latest_sim__c', '2022-05-19'),
#              ('SCOPUS_ID_sf__c', None),
#              ('ResearchGate_ID_sf__c', None),
#              ('ResearcherPresence_sf__c', False),
#              ('ResearchPresence_Notes_sf__c', None),
#              ('NH_bio__c', None),
#              ('NH_survey_results__c', None),
#              ('MaRDA_Survey_Link__c', None),
#              ('Notes_sf__c', None),
#              ('DB2_deleted__c', False),
#              ('nh_use_expire__c', '2023-05-01'),
#              ('new_prefs_expire__c', '2023-05-01'),
#              ('old_nh_optin__c', False),
#              ('Organization_sfnh_matched__c', None),
#              ('Group_Tags_Temp__c', None),
#              ('Lead_Owner__c', None),
#              ('LMS_Qualtrics_Survey__c', None),
#              ('LMS_expiration_date__c', None),
#              ('NCN_Team__c', False),
#              ('Salutation__c', None),
#              ('ML_Webinar_Attendee__c', False),
#              ('ML_Webinar_Registrant__c', False),
#              ('Recitation_Series_Attendee__c', True),
#              ('Recitation_Series_Registrant__c', False),
#              ('X2022_CustSat_Survey_Recipient__c', True),
#              ('Rec_Series_7_Registrant__c', False),
#              ('Rec_Series_1_Attendee__c', True),
#              ('Rec_Series_2_Attendee__c', False),
#              ('Rec_Series_3_Attendee__c', False),
#              ('Rec_Series_4_Attendee__c', False),
#              ('Rec_Series_5_Attendee__c', False),
#              ('Rec_Series_6_Attendee__c', False),
#              ('Rec_Series_1_Registrant__c', False),
#              ('Rec_Series_2_Registrant__c', False),
#              ('Rec_Series_3_Registrant__c', False),
#              ('Rec_Series_4_Registrant__c', False),
#              ('Rec_Series_5_Registrant__c', False),
#              ('Rec_Series_6_Registrant__c', False),
#              ('Expired_email__c', None),
#              ('MATLAB_Session_1_Registrant__c', False),
#              ('MATLAB_Session_2_Registrant__c', False),
#              ('MATLAB_Session_1_Attendee__c', False),
#              ('MATLAB_Session_2_Attendee__c', False),
#              ('Rec_Series_7_Attendee__c', False),
#              ('ML_1_Registrant__c', False),
#              ('ML_2_Registrant__c', False),
#              ('ML_3_Registrant__c', False),
#              ('ML_4_Registrant__c', False),
#              ('ML_5_Registrant__c', False),
#              ('ML_6_Registrant__c', False),
#              ('ML_7_Registrant__c', False),
#              ('ML_8_Registrant__c', False),
#              ('ML_9_Registrant__c', False),
#              ('ML_10_Registrant__c', False),
#              ('ML_11_Registrant__c', False),
#              ('ML_12_Registrant__c', False),
#              ('ML_13_Registrant__c', False),
#              ('ML_14_Registrant__c', False),
#              ('ML_15_Registrant__c', False),
#              ('ML_16_Registrant__c', False),
#              ('ML_17_Registrant__c', False),
#              ('ML_18_Registrant__c', False),
#              ('ML_19_Registrant__c', False),
#              ('ML_20_Registrant__c', False),
#              ('ML_21_Registrant__c', False),
#              ('ML_22_Registrant__c', False),
#              ('ML_23_Registrant__c', False),
#              ('ML_24_Registrant__c', False),
#              ('ML_25_Registrant__c', False),
#              ('ML_26_Registrant__c', False),
#              ('ML_27_Registrant__c', False),
#              ('ML_28_Registrant__c', False),
#              ('ML_1_Attendee__c', False),
#              ('ML_2_Attendee__c', False),
#              ('ML_3_Attendee__c', False),
#              ('ML_4_Attendee__c', False),
#              ('ML_5_Attendee__c', False),
#              ('ML_6_Attendee__c', False),
#              ('ML_7_Attendee__c', False),
#              ('ML_8_Attendee__c', False),
#              ('ML_9_Attendee__c', False),
#              ('ML_10_Attendee__c', False),
#              ('ML_11_Attendee__c', False),
#              ('ML_12_Attendee__c', False),
#              ('ML_13_Attendee__c', False),
#              ('ML_14_Attendee__c', False),
#              ('ML_15_Attendee__c', False),
#              ('ML_16_Attendee__c', False),
#              ('ML_17_Attendee__c', False),
#              ('ML_18_Attendee__c', False),
#              ('ML_19_Attendee__c', False),
#              ('ML_20_Attendee__c', False),
#              ('ML_21_Attendee__c', False),
#              ('ML_22_Attendee__c', False),
#              ('ML_23_Attendee__c', False),
#              ('ML_24_Attendee__c', False),
#              ('ML_25_Attendee__c', False),
#              ('ML_26_Attendee__c', False),
#              ('ML_27_Attendee__c', False),
#              ('ML_28_Attendee__c', False),
#              ('Rec_Series_Survey__c', False),
#              ('ECII_MOS_Capacitors__c', False),
#              ('ECII_ABACUS__c', False),
#              ('ECII_Bulk_semiconductors__c', False),
#              ('ECII_MOSFET__c', False),
#              ('ECII_Semiconductor_education__c', False),
#              ('ECII_Recitation_Series__c', False),
#              ('ECII_Crystal_Viewer__c', False),
#              ('ECII_ATCAD_Lab__c', False),
#              ('ECII_PN_Junction_Lab__c', False),
#              ('Rec_Series_1v2_Attendee__c', False),
#              ('Rec_Series_2v2_Attendee__c', False),
#              ('Rec_Series_3v2_Attendee__c', False),
#              ('Rec_Series_4v2_Attendee__c', False),
#              ('Rec_Series_5v2_Attendee__c', False),
#              ('Rec_Series_6v2_Attendee__c', False),
#              ('Rec_Series_7v2_Attendee__c', False),
#              ('Rec_Series_1v2_Registrant__c', False),
#              ('Rec_Series_2v2_Registrant__c', False),
#              ('Rec_Series_3v2_Registrant__c', False),
#              ('Rec_Series_4v2_Registrant__c', False),
#              ('Rec_Series_5v2_Registrant__c', False),
#              ('Rec_Series_6v2_Registrant__c', False),
#              ('Rec_Series_7v2_Registrant__c', False),
#              ('ML_29_Attendee__c', False),
#              ('ML_29_Registrant__c', False)])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 contact1 = contact_mapper.find_by_username('1vineetkumarsingh')
#       2 print(contact1['attributes'])
#       3 print(contact1['Id'])
#
# File ~/nanoHUB/nanoHUB/infrastructure/salesforce/contact.py:95, in ContactMapper.find_by_username(self, username)
#      91 result = self.engine.Contact.get_by_custom_id(
#      92     ContactMappings.username, username
#      93 )
#      94 pprint.pprint(result, sort_dicts=False)
# ---> 95 return self.factory.construct_from(result)
#
# File ~/nanoHUB/nanoHUB/infrastructure/salesforce/contact.py:67, in ContactFactory.construct_from(self, result)
#      57 def construct_from(self, result: dict) -> Contact:
#      58     return Contact(ContactParams(
#      59         result[ContactMappings.id],
#      60         result[ContactMappings.username],
#      61         result[ContactMappings.email],
#      62         result[ContactMappings.registration_date],
#      63         result[ContactMappings.last_active_date],
#      64         ContactName(
#      65             result[ContactMappings.name],
#      66             result[ContactMappings.salutation],
# ---> 67             result[ContactMappings.first_name],
#      68             result[ContactMappings.middle_name],
#      69             result[ContactMappings.last_name]
#      70         ),
#      71         {'salesforce_id': result['Id']}
#      72     ))
#
# KeyError: 'firstname'

# %%
print(contact1)
