# %%
import pandas as pd
import numpy as np
from pprint import pprint
from nanoHUB.application import Application
from nanoHUB.configuration import ClusteringConfiguration
from nanoHUB.pipeline.geddes.data import get_default_s3_client, read_all
from nanoHUB.dataaccess.lake import S3FileMapper



# logger.debug('Testing')
application = Application.get_instance()
nanohub_db = application.new_db_engine('nanohub')

#salesforce = application.new_salesforce_engine()

s3_client = get_default_s3_client(application)
bucket_name = ClusteringConfiguration().bucket_name_raw
tool_start_path = 'nanohub_metrics/toolstart'

raw_mapper = S3FileMapper(s3_client, bucket_name)
# Out:
# nanoHUB - Serving Students, Researchers & Instructors

# %%
parse_dates = ['datetime']
df = read_all(
    s3_client, 
    bucket_name, 
    tool_start_path
)
df['datetime'] = pd.to_datetime(df['datetime'])
# Out:
# {'Key': 'nanohub_metrics/toolstart/2005-01-01.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 22, 154000, tzinfo=tzlocal()), 'ETag': '"25cc355c0be9bab93f0883a92c9fe7bb"', 'Size': 13734, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-02.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 22, 212000, tzinfo=tzlocal()), 'ETag': '"097ae403dcc2af6d9a09250e0bf0e229"', 'Size': 13839, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-03.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 22, 268000, tzinfo=tzlocal()), 'ETag': '"a41038e63c4d942fb486f988b7d0b526"', 'Size': 9617, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-04.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 22, 324000, tzinfo=tzlocal()), 'ETag': '"eef60c388e4b5d6c5f460866885654d4"', 'Size': 13694, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-05.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 22, 382000, tzinfo=tzlocal()), 'ETag': '"ac0c6f7367bb177df4971a0c7a30caf0"', 'Size': 13943, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-06.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 22, 439000, tzinfo=tzlocal()), 'ETag': '"2e51c31053e8dcd8658facccff1899b5"', 'Size': 13499, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-07.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 22, 496000, tzinfo=tzlocal()), 'ETag': '"d47c3366d2d224c41318e4433ce124e2"', 'Size': 13510, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-08.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 22, 553000, tzinfo=tzlocal()), 'ETag': '"b9e1fee5029e80c4ae8d87270c1e75dc"', 'Size': 14445, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-09.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 22, 610000, tzinfo=tzlocal()), 'ETag': '"604f6c63a06e8487cd4328dc1205ee7a"', 'Size': 13935, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-10.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 22, 667000, tzinfo=tzlocal()), 'ETag': '"1e36eaea2255d1b1e32c948682e2b919"', 'Size': 13261, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-11.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 22, 729000, tzinfo=tzlocal()), 'ETag': '"0684bcccd5aa1468198d09850251a9e1"', 'Size': 16645, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-12.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 22, 789000, tzinfo=tzlocal()), 'ETag': '"b244907d1c733d9adf22ee2dcdae2da6"', 'Size': 16287, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-13.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 22, 849000, tzinfo=tzlocal()), 'ETag': '"9a2ec7cf5d3a04723f782fbc21c4130f"', 'Size': 15895, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-14.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 22, 911000, tzinfo=tzlocal()), 'ETag': '"84d4444ceb9dd010ea1880e6555455cf"', 'Size': 15674, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-15.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 22, 969000, tzinfo=tzlocal()), 'ETag': '"eed29ea64613dc158ca850b1ed8582b6"', 'Size': 14242, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-16.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 23, 29000, tzinfo=tzlocal()), 'ETag': '"99bbe0d4b35cd1fff146ccba4061a3eb"', 'Size': 14921, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-17.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 23, 86000, tzinfo=tzlocal()), 'ETag': '"ff11189af2ea2be5da591f404c268f5e"', 'Size': 13328, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-18.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 23, 146000, tzinfo=tzlocal()), 'ETag': '"98645a82de7060785c5535a67a76fe86"', 'Size': 14319, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-19.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 23, 206000, tzinfo=tzlocal()), 'ETag': '"f969e7d0b025fcf5f4e19b866462564d"', 'Size': 15888, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-20.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 23, 268000, tzinfo=tzlocal()), 'ETag': '"d69d8f63fe050ab73617587340a1425c"', 'Size': 17339, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-21.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 23, 328000, tzinfo=tzlocal()), 'ETag': '"f3757bfe768245e6735c77cddfa68a22"', 'Size': 15590, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-22.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 23, 384000, tzinfo=tzlocal()), 'ETag': '"6f5e8444dd3293fbde96dda0a274f823"', 'Size': 14683, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-23.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 23, 441000, tzinfo=tzlocal()), 'ETag': '"d4b25a1ee358d6af4b493e4017cdd171"', 'Size': 13320, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-24.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 23, 498000, tzinfo=tzlocal()), 'ETag': '"e4de329c8608f57bdae32449cfaf5faa"', 'Size': 13877, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-25.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 23, 556000, tzinfo=tzlocal()), 'ETag': '"58fa6b7ff3a723981994f5462e7b2260"', 'Size': 14526, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-26.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 23, 622000, tzinfo=tzlocal()), 'ETag': '"5c55e7503a8ce8ad936bfea5ffd3d703"', 'Size': 17791, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-27.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 23, 689000, tzinfo=tzlocal()), 'ETag': '"48badbaa6a3d813f36b0fd3892f34ab7"', 'Size': 19100, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-28.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 23, 756000, tzinfo=tzlocal()), 'ETag': '"d6c9958c7a193cfeb2ec5158b352dbd6"', 'Size': 18825, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-29.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 23, 821000, tzinfo=tzlocal()), 'ETag': '"ae9b9cc1eeaba821570a0c2ae51340a9"', 'Size': 17301, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-30.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 23, 885000, tzinfo=tzlocal()), 'ETag': '"9edb19af152e3102d05227f7fad61b79"', 'Size': 18208, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-01-31.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 23, 954000, tzinfo=tzlocal()), 'ETag': '"797cd8bdd1b7a507791d13cd1b992b51"', 'Size': 22252, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-01.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 24, 23000, tzinfo=tzlocal()), 'ETag': '"060706691aab53587205edb737498df3"', 'Size': 20737, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-02.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 24, 87000, tzinfo=tzlocal()), 'ETag': '"48f58e9d87eff7ce9fc1f9db0f42c0ac"', 'Size': 17071, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-03.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 24, 156000, tzinfo=tzlocal()), 'ETag': '"aad3eda09d8b79120ac57602aab1dc67"', 'Size': 20006, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-04.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 24, 225000, tzinfo=tzlocal()), 'ETag': '"15a985b5c490d2259cfdf581e61ffa48"', 'Size': 19537, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-05.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 24, 293000, tzinfo=tzlocal()), 'ETag': '"21c3df7e81cf8ce8548c9d277050741d"', 'Size': 18919, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-06.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 24, 357000, tzinfo=tzlocal()), 'ETag': '"a8c681d6b54ae9fed7ff174ad483dfa3"', 'Size': 16618, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-07.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 24, 423000, tzinfo=tzlocal()), 'ETag': '"c34ce3b02a22ed159806f620bd0b80d7"', 'Size': 19929, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-08.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 24, 494000, tzinfo=tzlocal()), 'ETag': '"61d9a19b89865e761b523824b2dffc67"', 'Size': 21961, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-09.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 24, 564000, tzinfo=tzlocal()), 'ETag': '"40a1b885b5dfee1b68dd89a78b50b05e"', 'Size': 27548, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-10.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 24, 657000, tzinfo=tzlocal()), 'ETag': '"abe5d3679213630f875eb70c2d74414b"', 'Size': 34521, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-11.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 24, 716000, tzinfo=tzlocal()), 'ETag': '"3f5bb2b9d36cf5162842df433f2141d0"', 'Size': 14518, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-12.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 24, 775000, tzinfo=tzlocal()), 'ETag': '"ec032a95d7648fb500d31ec78b34d5bf"', 'Size': 13848, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-13.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 24, 833000, tzinfo=tzlocal()), 'ETag': '"f7665e06d6f915d99f11cebd2aeba4f5"', 'Size': 13433, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-14.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 24, 897000, tzinfo=tzlocal()), 'ETag': '"ee6d31e59d61a8800f94712070b8d719"', 'Size': 16916, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-15.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 24, 963000, tzinfo=tzlocal()), 'ETag': '"5cdc6cd024273b868726b157006ed606"', 'Size': 18834, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-16.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 25, 32000, tzinfo=tzlocal()), 'ETag': '"b5de750bbca5b8dbbe594886821fa5f1"', 'Size': 20087, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-17.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 25, 113000, tzinfo=tzlocal()), 'ETag': '"76bd0c7aa84c3a24f69879734f2da66a"', 'Size': 34064, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-18.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 25, 174000, tzinfo=tzlocal()), 'ETag': '"9a814650c3ba94b932aa27d8a76a01fb"', 'Size': 15445, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-19.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 25, 237000, tzinfo=tzlocal()), 'ETag': '"24222944132ce26f9762022ad1aa690b"', 'Size': 16468, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-20.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 25, 299000, tzinfo=tzlocal()), 'ETag': '"6207b79bcd5de1b698c35dc4037af548"', 'Size': 15511, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-21.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 25, 365000, tzinfo=tzlocal()), 'ETag': '"3649442cddccc977e1b162fd69e53361"', 'Size': 18379, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-22.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 25, 430000, tzinfo=tzlocal()), 'ETag': '"072545c74decc0328d24a6a2128fb510"', 'Size': 18791, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-23.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 25, 497000, tzinfo=tzlocal()), 'ETag': '"a1afbf58d5f3fbb7635ece33f7a8252c"', 'Size': 18705, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-24.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 25, 569000, tzinfo=tzlocal()), 'ETag': '"3f1d1a5808c27db279457a63b74d7d13"', 'Size': 27955, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-25.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 25, 638000, tzinfo=tzlocal()), 'ETag': '"90c85e52915e9dedf6e96ff304f54ff4"', 'Size': 19756, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-26.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 25, 706000, tzinfo=tzlocal()), 'ETag': '"48f3f411c90ddec48d3e273ab36a593c"', 'Size': 19494, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-27.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 25, 766000, tzinfo=tzlocal()), 'ETag': '"0860e5662dbb095b5d125352c5658cc7"', 'Size': 14731, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-02-28.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 25, 920000, tzinfo=tzlocal()), 'ETag': '"956e28ce818cddceb3f8ef2d6988d321"', 'Size': 17948, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-03-01.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 25, 985000, tzinfo=tzlocal()), 'ETag': '"b07763fe2cdb0681515a1672e4804f90"', 'Size': 19018, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-03-02.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 26, 53000, tzinfo=tzlocal()), 'ETag': '"03b6f8937aa2f9efcde2b057e24e0a1b"', 'Size': 20930, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-03-03.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 26, 130000, tzinfo=tzlocal()), 'ETag': '"6bf8c7d4ad0e98998ce147ef127a2a55"', 'Size': 32336, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-03-04.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 26, 204000, tzinfo=tzlocal()), 'ETag': '"cbcbacef2f23c467ec78e3888df75d08"', 'Size': 23481, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-03-05.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 26, 266000, tzinfo=tzlocal()), 'ETag': '"140805dbfe461ba78e692e490fb6f603"', 'Size': 16626, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-03-06.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 26, 329000, tzinfo=tzlocal()), 'ETag': '"96c0003caece61ccdd49ba59d9896fdb"', 'Size': 16266, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-03-07.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 26, 397000, tzinfo=tzlocal()), 'ETag': '"2ff394efff0e462b339df9772137570c"', 'Size': 20024, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-03-08.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 26, 469000, tzinfo=tzlocal()), 'ETag': '"32de6a7b6dd10a3a8d9bbc90657eae57"', 'Size': 22283, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-03-09.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 26, 542000, tzinfo=tzlocal()), 'ETag': '"09183b18c84783d113686a66b9ec605a"', 'Size': 27857, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-03-10.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 26, 635000, tzinfo=tzlocal()), 'ETag': '"7752395aa61f77d044e3c92991182c84"', 'Size': 35721, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-03-11.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 26, 705000, tzinfo=tzlocal()), 'ETag': '"7b2f1aa94161254ddb0b31717b431e18"', 'Size': 22323, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-03-12.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 26, 769000, tzinfo=tzlocal()), 'ETag': '"c4602b3d7cf54cf34c52fde815806ede"', 'Size': 16725, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-03-13.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 26, 831000, tzinfo=tzlocal()), 'ETag': '"583ecbf7890de425bb17b0cbf2eaffbf"', 'Size': 14966, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-03-14.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 26, 893000, tzinfo=tzlocal()), 'ETag': '"9e19e69ab0a65c8fc27bd95ce8d8d44e"', 'Size': 15214, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-03-15.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 26, 954000, tzinfo=tzlocal()), 'ETag': '"7fc036ed20e487b1c049f6d8e258a87a"', 'Size': 16294, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-03-16.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 27, 21000, tzinfo=tzlocal()), 'ETag': '"db7745e2a934f284eaa8ac1c7342c886"', 'Size': 17671, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-03-17.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 27, 85000, tzinfo=tzlocal()), 'ETag': '"caae210410d6ad4f5769635c77efe63f"', 'Size': 16593, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-03-18.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 27, 146000, tzinfo=tzlocal()), 'ETag': '"135349b3d4fbee89ade2637ab18a090d"', 'Size': 16475, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-03-19.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 27, 203000, tzinfo=tzlocal()), 'ETag': '"f724a2a369971a594508696cc5453a9e"', 'Size': 14087, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-03-20.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 27, 258000, tzinfo=tzlocal()), 'ETag': '"fb5e62034de84fa04a2940354f05486f"', 'Size': 13771, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-03-21.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 27, 329000, tzinfo=tzlocal()), 'ETag': '"29552947a6ec7ea70e87f38a0bb44b5c"', 'Size': 19901, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-03-22.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 27, 397000, tzinfo=tzlocal()), 'ETag': '"9eeacbba5d637b69be587349a061d55b"', 'Size': 18587, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-03-23.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 27, 461000, tzinfo=tzlocal()), 'ETag': '"744e4691ea902d1655a74305ea01d18b"', 'Size': 24472, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-03-24.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 27, 568000, tzinfo=tzlocal()), 'ETag': '"2efdcaee11ccc9be89e12c6ddc64911c"', 'Size': 45442, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-03-25.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 27, 631000, tzinfo=tzlocal()), 'ETag': '"76f0703fac291cc27836996c4950b92e"', 'Size': 16132, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-03-26.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 27, 700000, tzinfo=tzlocal()), 'ETag': '"045516676644ee8d034afc5e9bbfeb72"', 'Size': 20253, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}
# {'Key': 'nanohub_metrics/toolstart/2005-03-27.parquet.gzip', 'LastModified': datetime.datetime(2022, 3, 2, 19, 58, 27, 758000, tzinfo=tzlocal()), 'ETag': '"7ec1e732f270a0cbd9773e4de729d7de"', 'Size': 14511, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'Praveen Saxena', 'ID': 'saxenap'}}

# %%
display(df)
# Out:
#             id sessionid            datetime orgtype countryresident  \
# 0            1         0 2002-07-01 05:58:29       0
# 1            2         0 2002-07-01 08:19:59       0
# 2            3         0 2002-07-01 08:25:48       0
# 3            4         0 2002-07-01 08:39:10       0
# 4            5         0 2002-07-01 08:52:17       0
# ...        ...       ...                 ...     ...             ...
# 183915  413009    308076 2005-03-26 19:31:19       0
# 183916  413010    308076 2005-03-26 19:31:31       0
# 183917  413011    308076 2005-03-26 19:51:42       0
# 183918  413012    308076 2005-03-26 19:56:48       0
# 183919  413013    308076 2005-03-26 19:57:40       0
#
#        countrycitizen protocol success countryip               ip  \
# 0                            5       1        NL  130.161.187.159
# 1                            5       1        US   147.226.50.102
# 2                            5       1        US   147.226.50.102
# 3                            5       1        US   147.226.50.102
# 4                            5       1        US   147.226.50.102
# ...               ...      ...     ...       ...              ...
# 183915                       5       1        US   128.46.190.140
# 183916                       5       1        US   128.46.190.140
# 183917                       5       1        US   128.46.190.140
# 183918                       5       1        US   128.46.190.140
# 183919                       5       1        US   128.46.190.140
#
#                               host      user       tool    pid      domain  \
# 0           frohlich.tn.tudelft.nl     herre     CNT-IV    1.0  tudelft.nl
# 1       nat-147-226-50-102.bsu.edu   donovan  Huckel-IV  340.0     bsu.edu
# 2       nat-147-226-50-102.bsu.edu   donovan  Huckel-IV  341.0     bsu.edu
# 3       nat-147-226-50-102.bsu.edu   donovan  Huckel-IV  342.0     bsu.edu
# 4       nat-147-226-50-102.bsu.edu   donovan  Huckel-IV  343.0     bsu.edu
# ...                            ...       ...        ...    ...         ...
# 183915   me190pc148.ecn.purdue.edu  maroofhk   TSuprem4   54.0  purdue.edu
# 183916   me190pc148.ecn.purdue.edu  maroofhk   TSuprem4   55.0  purdue.edu
# 183917   me190pc148.ecn.purdue.edu  maroofhk   TSuprem4   56.0  purdue.edu
# 183918   me190pc148.ecn.purdue.edu  maroofhk   TSuprem4   57.0  purdue.edu
# 183919   me190pc148.ecn.purdue.edu  maroofhk   TSuprem4   58.0  purdue.edu
#
#        filesystem                 execunit walltime cputime error
# 0            none  babylon5.ecn.purdue.edu      139      -1  None
# 1            none  babylon5.ecn.purdue.edu      107      -1  None
# 2            none  babylon5.ecn.purdue.edu      337      -1  None
# 3            none  babylon5.ecn.purdue.edu      206      -1  None
# 4            none  babylon5.ecn.purdue.edu      259      -1  None
# ...           ...                      ...      ...     ...   ...
# 183915       none      jedi.ecn.purdue.edu        4      -1  None
# 183916       none      jedi.ecn.purdue.edu        6      -1  None
# 183917       none      jedi.ecn.purdue.edu        7      -1  None
# 183918       none      jedi.ecn.purdue.edu        5      -1  None
# 183919       none      jedi.ecn.purdue.edu        5      -1  None
#
# [183920 rows x 20 columns]

# %%
df = df.sort_values(by="datetime")
display(df.tail())
# Out:
#             id sessionid            datetime orgtype countryresident  \
# 183915  413009    308076 2005-03-26 19:31:19       0
# 183916  413010    308076 2005-03-26 19:31:31       0
# 183917  413011    308076 2005-03-26 19:51:42       0
# 183918  413012    308076 2005-03-26 19:56:48       0
# 183919  413013    308076 2005-03-26 19:57:40       0
#
#        countrycitizen protocol success countryip              ip  \
# 183915                       5       1        US  128.46.190.140
# 183916                       5       1        US  128.46.190.140
# 183917                       5       1        US  128.46.190.140
# 183918                       5       1        US  128.46.190.140
# 183919                       5       1        US  128.46.190.140
#
#                              host      user      tool   pid      domain  \
# 183915  me190pc148.ecn.purdue.edu  maroofhk  TSuprem4  54.0  purdue.edu
# 183916  me190pc148.ecn.purdue.edu  maroofhk  TSuprem4  55.0  purdue.edu
# 183917  me190pc148.ecn.purdue.edu  maroofhk  TSuprem4  56.0  purdue.edu
# 183918  me190pc148.ecn.purdue.edu  maroofhk  TSuprem4  57.0  purdue.edu
# 183919  me190pc148.ecn.purdue.edu  maroofhk  TSuprem4  58.0  purdue.edu
#
#        filesystem             execunit walltime cputime error
# 183915       none  jedi.ecn.purdue.edu        4      -1  None
# 183916       none  jedi.ecn.purdue.edu        6      -1  None
# 183917       none  jedi.ecn.purdue.edu        7      -1  None
# 183918       none  jedi.ecn.purdue.edu        5      -1  None
# 183919       none  jedi.ecn.purdue.edu        5      -1  None

# %%
test = raw_mapper.read(tool_start_path + '/2017')
display(test)
# Out:
#            id  sessionid            datetime  orgtype countryresident  \
# 0     9820570          0 2017-12-30 00:00:57        0
# 1     9820571          0 2017-12-30 00:01:00        0
# 2     9819488          0 2017-12-30 00:36:05        7              US
# 3     9820572          0 2017-12-30 01:00:28        0
# 4     9820574          0 2017-12-30 01:03:06        0
# ...       ...        ...                 ...      ...             ...
# 2208  9821475          0 2017-12-30 23:44:02        0
# 2209  9821476          0 2017-12-30 23:47:02        0
# 2210  9821477          0 2017-12-30 23:47:02        0
# 2211  9821478          0 2017-12-30 23:49:21        0
# 2212  9821479          0 2017-12-30 23:49:21        0
#
#      countrycitizen  protocol  success countryip              ip  \
# 0                           7        1        US   172.21.233.40
# 1                           7        1        US   172.21.233.40
# 2                CN         7        1        US  173.230.58.120
# 3                           7        1        IN    49.15.69.235
# 4                           7        1        IN    49.15.69.235
# ...             ...       ...      ...       ...             ...
# 2208                        7        1        US   24.60.248.228
# 2209                        7        1        US   24.60.248.228
# 2210                        7        1        US   24.60.248.228
# 2211                        7        1        US   24.60.248.228
# 2212                        7        1        US   24.60.248.228
#
#                                                    host  \
# 0               vpnclient-ipsec-233-040.itap.purdue.edu
# 1               vpnclient-ipsec-233-040.itap.purdue.edu
# 2     host-58-120.inlaklo.westlafayette.in.us.client...
# 3                                                     ?
# 4                                                     ?
# ...                                                 ...
# 2208                c-24-60-248-228.hsd1.ma.comcast.net
# 2209                c-24-60-248-228.hsd1.ma.comcast.net
# 2210                c-24-60-248-228.hsd1.ma.comcast.net
# 2211                c-24-60-248-228.hsd1.ma.comcast.net
# 2212                c-24-60-248-228.hsd1.ma.comcast.net
#
#                        user            tool   pid           domain filesystem  \
# 0                  chen2057    jupyter44_r3  None       purdue.edu       None
# 1                  chen2057    jupyter44_r3  None       purdue.edu       None
# 2                     jin52   workspace_r12  None  pavlovmedia.net       None
# 3               er.pankaj08  nanofinfet_r92  None                ?       None
# 4               er.pankaj08  nanofinfet_r92  None                ?       None
# ...                     ...             ...   ...              ...        ...
# 2208  ericluoweijun2007cool      dftqe_r111  None      comcast.net       None
# 2209  ericluoweijun2007cool      dftqe_r111  None      comcast.net       None
# 2210  ericluoweijun2007cool      dftqe_r111  None      comcast.net       None
# 2211  ericluoweijun2007cool      dftqe_r111  None      comcast.net       None
# 2212  ericluoweijun2007cool      dftqe_r111  None      comcast.net       None
#
#      execunit  walltime  cputime error
# 0     exec024         5       28  None
# 1     exec024     86422        1  None
# 2     exec025       676        5  None
# 3     exec022     39544       94  None
# 4     exec022        88       85  None
# ...       ...       ...      ...   ...
# 2208  exec028        12        9  None
# 2209  exec028        25        6  None
# 2210  exec028         7        6  None
# 2211  exec028         0       -1  None
# 2212  exec028        45       -1  None
#
# [2213 rows x 20 columns]

# %%
# k = 0
# for key in s3_client.list_objects(Bucket=ClusteringConfiguration().bucket_name_raw, Prefix='nanohub_metrics/toolstart/2017')['Contents']:
#     obj = s3_client.get_object(Bucket=ClusteringConfiguration().bucket_name_raw, Key=key['Key'])
#     print(key)
#     k = k + 1
#     if k == 100:
#         break
