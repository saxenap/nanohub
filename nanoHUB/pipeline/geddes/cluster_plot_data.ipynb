# %%
import datetime
import pandas as pd
from nanoHUB.application import Application
from nanoHUB.configuration import ClusteringConfiguration
from nanoHUB.clustering.infra import get_cluster_numbers_by_semester
from nanoHUB.pandas_helper import remove_display_restrictions

remove_display_restrictions(pd)

application = Application.get_instance()
# Out:
# nanoHUB - Serving Students, Researchers & Instructors

# %%
data_df = get_cluster_numbers_by_semester(application, ClusteringConfiguration().bucket_name_processed)
display(data_df)
# Out:
#     year     sem  number of all registered users  \
# 0   2008  spring                           25465
# 1   2008    fall                           29068
# 2   2009  spring                           32824
# 3   2009    fall                           36503
# 4   2010  spring                           41508
# 5   2010    fall                           46468
# 6   2011  spring                           51991
# 7   2011    fall                           57589
# 8   2012  spring                           64224
# 9   2012    fall                           70038
# 10  2013  spring                           78248
# 11  2013    fall                           85577
# 12  2014  spring                           93893
# 13  2014    fall                          101469
# 14  2015  spring                          110497
# 15  2015    fall                          118247
# 16  2016  spring                          126033
# 17  2016    fall                          137083
# ...
