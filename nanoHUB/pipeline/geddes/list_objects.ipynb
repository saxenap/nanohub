# %%
from nanoHUB.application import Application
from nanoHUB.pipeline.geddes.data import get_default_s3_client
import pandas as pd
from io import BytesIO,StringIO

application = Application.get_instance()
s3_client = get_default_s3_client(application)

bucket_name_raw = 'nanohub.raw'
bucket_name_processed = 'nanohub.processed'
# Out:
# nanoHUB - Serving Students, Researchers & Instructors

# %%
objs = s3_client.list_objects(Bucket=bucket_name_raw, Prefix='nanohub_metrics/toolevents/by_semester/')['Contents']
print(len(objs))

for obj in objs:
    _obj = s3_client.get_object(Bucket=bucket_name_raw, Key=obj['Key'])
    print(obj['Key'])
# Out:
# 26
# nanohub_metrics/toolevents/by_semester/2008-01-01_2008-07-01.parquet.gzip
# nanohub_metrics/toolevents/by_semester/2008-07-02_2008-12-31.parquet.gzip
# nanohub_metrics/toolevents/by_semester/2009-01-01_2009-07-01.parquet.gzip
# nanohub_metrics/toolevents/by_semester/2009-07-02_2009-12-31.parquet.gzip
# nanohub_metrics/toolevents/by_semester/2010-01-01_2010-07-01.parquet.gzip
# nanohub_metrics/toolevents/by_semester/2010-07-02_2010-12-31.parquet.gzip
# nanohub_metrics/toolevents/by_semester/2011-01-01_2011-07-01.parquet.gzip
# nanohub_metrics/toolevents/by_semester/2011-07-02_2011-12-31.parquet.gzip
# nanohub_metrics/toolevents/by_semester/2012-01-01_2012-07-01.parquet.gzip
# nanohub_metrics/toolevents/by_semester/2012-07-02_2012-12-31.parquet.gzip
# nanohub_metrics/toolevents/by_semester/2013-01-01_2013-07-01.parquet.gzip
# nanohub_metrics/toolevents/by_semester/2013-07-02_2013-12-31.parquet.gzip
# nanohub_metrics/toolevents/by_semester/2014-01-01_2014-07-01.parquet.gzip
# ...

# %%
# Out:
# Listing files in bucket: nanohub.processed
# 28
# File name: cost_cluster_analysis/by_semester/2008-01-01_2008-07-01.csv
# File name: cost_cluster_analysis/by_semester/2008-07-02_2008-12-31.csv
# File name: cost_cluster_analysis/by_semester/2009-01-01_2009-07-01.csv
# File name: cost_cluster_analysis/by_semester/2009-07-02_2009-12-31.csv
# File name: cost_cluster_analysis/by_semester/2010-01-01_2010-07-01.csv
# File name: cost_cluster_analysis/by_semester/2010-07-02_2010-12-31.csv
# File name: cost_cluster_analysis/by_semester/2011-01-01_2011-07-01.csv
# File name: cost_cluster_analysis/by_semester/2011-07-02_2011-12-31.csv
# File name: cost_cluster_analysis/by_semester/2012-01-01_2012-07-01.csv
# File name: cost_cluster_analysis/by_semester/2012-07-02_2012-12-31.csv
# File name: cost_cluster_analysis/by_semester/2013-01-01_2013-07-01.csv
# File name: cost_cluster_analysis/by_semester/2013-07-02_2013-12-31.csv
# File name: cost_cluster_analysis/by_semester/2014-01-01_2014-07-01.csv
# ...

# %%
for obj in s3_client.list_objects(Bucket='nanohub.raw', Prefix='nanohub/jos_users/2021-')['Contents']:
    print(obj['Key'])
# Out:
# nanohub/jos_users/2021-01-01.parquet.gzip
# nanohub/jos_users/2021-01-02.parquet.gzip
# nanohub/jos_users/2021-01-03.parquet.gzip
# nanohub/jos_users/2021-01-04.parquet.gzip
# nanohub/jos_users/2021-01-05.parquet.gzip
# nanohub/jos_users/2021-01-06.parquet.gzip
# nanohub/jos_users/2021-01-07.parquet.gzip
# nanohub/jos_users/2021-01-08.parquet.gzip
# nanohub/jos_users/2021-01-09.parquet.gzip
# nanohub/jos_users/2021-01-10.parquet.gzip
# nanohub/jos_users/2021-01-11.parquet.gzip
# nanohub/jos_users/2021-01-12.parquet.gzip
# nanohub/jos_users/2021-01-13.parquet.gzip
# nanohub/jos_users/2021-01-14.parquet.gzip
# nanohub/jos_users/2021-01-15.parquet.gzip
# nanohub/jos_users/2021-01-16.parquet.gzip
# nanohub/jos_users/2021-01-17.parquet.gzip
# nanohub/jos_users/2021-01-18.parquet.gzip
# nanohub/jos_users/2021-01-19.parquet.gzip
# nanohub/jos_users/2021-01-20.parquet.gzip
# nanohub/jos_users/2021-01-21.parquet.gzip
# nanohub/jos_users/2021-01-22.parquet.gzip
# ...

# %%
buckets = ['nanohub.processed']

for bucket_name in buckets:

    print("\nListing files in bucket: %s" % bucket_name)
    objs = s3_client.list_objects(Bucket=bucket_name, Prefix='cost_cluster_analysis/')['Contents']
    print(len(objs))
    for obj in objs:
        print("File name: %s" % obj['Key'])
# Out:
# Listing files in bucket: nanohub.processed
# 28
# File name: cost_cluster_analysis/by_semester/2008-01-01_2008-07-01.csv
# File name: cost_cluster_analysis/by_semester/2008-07-02_2008-12-31.csv
# File name: cost_cluster_analysis/by_semester/2009-01-01_2009-07-01.csv
# File name: cost_cluster_analysis/by_semester/2009-07-02_2009-12-31.csv
# File name: cost_cluster_analysis/by_semester/2010-01-01_2010-07-01.csv
# File name: cost_cluster_analysis/by_semester/2010-07-02_2010-12-31.csv
# File name: cost_cluster_analysis/by_semester/2011-01-01_2011-07-01.csv
# File name: cost_cluster_analysis/by_semester/2011-07-02_2011-12-31.csv
# File name: cost_cluster_analysis/by_semester/2012-01-01_2012-07-01.csv
# File name: cost_cluster_analysis/by_semester/2012-07-02_2012-12-31.csv
# File name: cost_cluster_analysis/by_semester/2013-01-01_2013-07-01.csv
# File name: cost_cluster_analysis/by_semester/2013-07-02_2013-12-31.csv
# File name: cost_cluster_analysis/by_semester/2014-01-01_2014-07-01.csv
# ...

# %%
for key in s3_client.list_objects(Bucket='nanohub.processed', Prefix='cost_cluster_analysis/by_semester/2008-01-01_2008-07-01')['Contents']:
    print(key['Key'])
    obj = s3_client.get_object(Bucket='nanohub.processed', Key=key['Key'])
    if key['Key'].endswith('.parquet.gzip'):
        df = pd.read_parquet(BytesIO(obj['Body'].read()))
    else:
        df = pd.read_csv(BytesIO(obj['Body'].read()))
    
    display(df)
# Out:
# cost_cluster_analysis/by_semester/2008-01-01_2008-07-01.csv
#                0             1            2              3           4  \
# 0      pcappaert       ratatat       sab266           mmui  dgrossheim
# 1        EDutton        jli942         scho      deflipp14    wolf1988
# 2      greatsisi  ahmed_3anter       mfarag             SH         shn
# 3      Khunwasut         jsirk  tresprynter        afang29     atanase
# 4      hdudumoni     bromeo710   mallik69sg  anupsasikumar     cboztug
# ..           ...           ...          ...            ...         ...
# 61   srubinstein     nlopez006        schoi       smcnulty  rortenberg
# 62       rthomas   mikaelcasse       dykaar     usantander    ampadova
# 63       chs3869        dkttk4      hisanta      gidwldl86     qzhang1
# 64      jkitchin      urmimala    Sebastian         flynux      fberte
# 65  riyashergill      kabulski       tim123         marent    sumitash
#
# ...

# %%
buckets = ['nanohub.processed']

for bucket_name in buckets:

    print("\nListing files in bucket: %s" % bucket_name)
    objs = s3_client.list_objects(Bucket=bucket_name, Prefix='clusters/xufeng/by_semester/2008-01-01_2008-07-01')['Contents']
    print(len(objs))
    for obj in objs:
        print("File name: %s" % obj['Key'])
# Out:
# Listing files in bucket: nanohub.processed
# 10
# File name: clusters/xufeng/by_semester/2008-01-01_2008-07-01/class_info_df.csv
# File name: clusters/xufeng/by_semester/2008-01-01_2008-07-01/classtool_info_df.csv
# File name: clusters/xufeng/by_semester/2008-01-01_2008-07-01/cluster_output_candidate.csv
# File name: clusters/xufeng/by_semester/2008-01-01_2008-07-01/cluster_post_sychrony.csv
# File name: clusters/xufeng/by_semester/2008-01-01_2008-07-01/detected_clusters_df.csv
# File name: clusters/xufeng/by_semester/2008-01-01_2008-07-01/intra_tool_cluster_df.csv
# File name: clusters/xufeng/by_semester/2008-01-01_2008-07-01/jos_users.csv
# File name: clusters/xufeng/by_semester/2008-01-01_2008-07-01/students_info_df.csv
# File name: clusters/xufeng/by_semester/2008-01-01_2008-07-01/toolrun_df.csv
# File name: clusters/xufeng/by_semester/2008-01-01_2008-07-01/user_activity_blocks_df.csv

# %%
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', None)  # or 199

# for key in s3_client.list_objects(Bucket='nanohub.processed', Prefix='clusters/xufeng/by_semester/2008-01-01_2008-07-01/intra_tool_cluster_df.csv')['Contents']:
#     obj = s3_client.get_object(Bucket='nanohub.processed', Key=key['Key'])
#     if key['Key'].endswith('.parquet.gzip'):
#         df = pd.read_parquet(BytesIO(obj['Body'].read()))
#     else:
#         df = pd.read_csv(BytesIO(obj['Body'].read()))

# from IPython.core.display import HTML
# display(HTML(df.to_html()))

# print(df['user_set'])


print('#########################################################################################################')
print('#########################################################################################################')

for key in s3_client.list_objects(Bucket='nanohub.processed', Prefix='clusters/xufeng/by_semester/2008-01-01_2008-07-01.csv')['Contents']:
    obj = s3_client.get_object(Bucket='nanohub.processed', Key=key['Key'])
    if key['Key'].endswith('.parquet.gzip'):
        df = pd.read_parquet(BytesIO(obj['Body'].read()))
    else:
        df = pd.read_csv(BytesIO(obj['Body'].read()), header=None)

# df[0] = df[0].str[1:-1]
# df[0] = df[0].str.replace("\'", "")

# rows = []
# for index, row in df.iterrows():
#     rows.append(row[0].split(', '))


# df = pd.DataFrame(rows)


display(df)


# df = pd.DataFrame(stdf.tolist()) # or stdf.apply(pd.Series)
# print(df['user_set'])
# Out:
# #########################################################################################################
# #########################################################################################################
#                   0               1                2                     3    \
# 0        mohannadyomn        mhmd1984      khashaba154        khallidkhallaf
# 1            sweetsal         wenshen         leteruel            bisrattaff
# 2            mhmd1984     khashaba154     kariembudran            ranya_samy
# 3                  sh         maged_1             Mimi             nasrantar
# 4            sweetsal      pranjali26      nanoguyunlv               wenshen
# 5            hari1234          rakesh           shinde              mshareef
# 6            mshareef   sravankumarga           swathi            yalavarthi
# 7            vineel86         arif999         ravi1986            malliksiuc
# ...

# %%
for key in s3_client.list_objects(Bucket='nanohub.processed', Prefix='clusters/xufeng/by_semester/2008-01-01_2008-07-01/user_activity_blocks_df.csv')['Contents']:
    print(key['Key'])
    obj = s3_client.get_object(Bucket='nanohub.processed', Key=key['Key'])
    if key['Key'].endswith('.parquet.gzip'):
        df = pd.read_parquet(BytesIO(obj['Body'].read()))
    else:
        df = pd.read_csv(BytesIO(obj['Body'].read()))
 
display(df.head())
df = df[['ip']]
display(df.head())
# Out:
# clusters/xufeng/by_semester/2008-01-01_2008-07-01/user_activity_blocks_df.csv
#       user      tool       start         end               ip        lon  \
# 0  02paiks  spice3f4  2008-04-13  2008-04-18    128.46.170.56 -86.914703
# 1  02paiks  spice3f4  2008-04-13  2008-04-18  128.211.176.152 -86.914703
# 2  02paiks  spice3f4  2008-04-13  2008-04-18    128.46.170.32 -86.914703
# 3  02paiks  spice3f4  2008-04-13  2008-04-18   128.211.179.61 -86.914703
# 4  02paiks  spice3f4  2008-04-05  2008-04-10   128.211.175.28 -86.914703
#
#          lat
# 0  40.425098
# 1  40.425098
# 2  40.425098
# 3  40.425098
# 4  40.425098
#                 ip
# 0    128.46.170.56
# 1  128.211.176.152
# 2    128.46.170.32
# 3   128.211.179.61
# 4   128.211.175.28

# %%
buckets = ['nanohub.raw']

for bucket_name in buckets:

    print("\nListing files in bucket: %s" % bucket_name)
    for key in s3_client.list_objects(Bucket=bucket_name, Prefix='clusters/xufeng/by_semester/2008-01-01_2008-07-01/detected_clusters_df.csv)['Contents']:
        print("File name: %s" % key['Key'])
# Out:
#   File "/tmp/ipykernel_450/3194887145.py", line 6
#     for key in s3_client.list_objects(Bucket=bucket_name, Prefix='clusters/xufeng/by_semester/2008-01-01_2008-07-01/detected_clusters_df.csv)['Contents']:
#                                                                                                                                                ^
# SyntaxError: invalid syntax

# %%
for bucket_name in buckets:

    print("Listing files in bucket: %s" % bucket_name)
    for key in s3_client.list_objects(Bucket=bucket_name)['Contents']:
        obj = s3_client.get_object(Bucket=bucket_name, Key=key['Key'])
        print("File name: %s" % key['Key'])
        if key['Key'].endswith('.parquet.gzip'):
            display(pd.read_parquet(BytesIO(obj['Body'].read())))
        else:
            display(pd.read_csv(BytesIO(obj['Body'].read())))
