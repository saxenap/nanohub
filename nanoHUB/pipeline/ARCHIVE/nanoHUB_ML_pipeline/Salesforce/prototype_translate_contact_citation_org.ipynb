# %% [markdown]
# # DB2-Salesforce connector: Prototype Translate contact and citation user-filled organization to match Organization object

# %%
# Parameters
hours_range = 24*365*30 # number of days to look back

# API settings
bulk_api_threshold = 100 # if more records than this, use Bulk API instead
disallow_bulk_api = False # if Bulk API is allowed

api_url = '/services/data/v43.0/sobjects'
external_id = 'nanoHUB_user_ID__c'
object_id = 'Contact'

# login parameters to be handled by Papermill
sf_login_params = None 
sql_login_params = None

# %%
# Parameters
sql_login_params = {"username": "wang159_ro", "password": "napoleon0"}
sf_login_params = {
    "grant_type": "password",
    "client_id": "3MVG95jctIhbyCppj0SNJ75IsZ1y8UPGZtSNF4j8FNVXz.De8Lu4jHm3rjRosAtsHy6qjHx3i4S_QbQzvBePG",
    "client_secret": "D1623C6D3607D4FC8004B92C761DFB6C1F70CCD129C5501E357028DFA00F5764",
    "username": "wang159-4j1v@force.com",
    "password": "napoleon0eZ3PQpQqE3C3z4wWqEqKGhQ8",
}

# %%
import pandas as pd
import datetime

# %% [markdown]
# ## Obtain contacts from DB2
# that have last visit date within range of interest specified by day_range

# %% [raw]
# MariaDB [nanohub]> select id, name, label from jos_user_profile_fields;
# +----+-----------------+-------------------------------------------------------+
# | id | name            | label                                                 |
# +----+-----------------+-------------------------------------------------------+
# |  1 | organization    | Organization                                          |
# |  2 | orgtype         | Organization / Position Type                          |
# |  3 | countryresident | Residency                                             |
# |  4 | countryorigin   | Citizenship                                           |
# |  5 | url             | Website                                               |
# |  6 | phone           | Telephone                                             |
# |  7 | orcid           | ORCID                                                 |
# |  8 | gender          | Gender                                                |
# |  9 | race            | Racial Background                                     |
# | 10 | disability      | Disability                                            |
# | 11 | reason          | Reason                                                |
# | 12 | tags            | Interests                                             |
# | 13 | address         | Address                                               |
# | 14 | hispanic        | Hispanic Heritage                                     |
# | 15 | bio             | Biography                                             |
# | 16 | howdidyouhear   | How did you first hear about nanoHUB?                 |
# | 17 | purposeofvisit  | What is the primary purpose of your visit to nanoHUB? |
# +----+-----------------+-------------------------------------------------------+
#
#
#
# MariaDB [nanohub]> explain  jos_user_profiles;
# +---------------+------------------+------+-----+---------+----------------+
# | Field         | Type             | Null | Key | Default | Extra          |
# +---------------+------------------+------+-----+---------+----------------+
# | id            | int(11) unsigned | NO   | PRI | NULL    | auto_increment |
# | user_id       | int(11)          | NO   | MUL | NULL    |                |
# | profile_key   | varchar(100)     | NO   |     | NULL    |                |
# | profile_value | text             | NO   |     | NULL    |                |
# | ordering      | int(11)          | NO   |     | 0       |                |
# | access        | int(10)          | NO   |     | 0       |                |
# +---------------+------------------+------+-----+---------+----------------+

# %%
# Depending on the task, use different query and cutoff

# Hourly update for new registrations
date_cutoff = (datetime.datetime.today().date() - datetime.timedelta(hours=hours_range))\
                    .strftime('%Y-%m-%d')
sql_query = "select id, name, username, block, email, sendEmail, registerDate, lastvisitDate \
                    from jos_users where registerDate >= '%s'" % date_cutoff

# display
print(sql_query)
# Out:
# select id, name, username, block, email, sendEmail, registerDate, lastvisitDate                     from jos_users where registerDate >= '1990-05-27'

# %%
# connect with DB2
import sqlalchemy as sql

engine = sql.create_engine('mysql+pymysql://%s:%s@127.0.0.1/nanohub' \
                                               %(sql_login_params['username'], sql_login_params['password']))
df = pd.read_sql_query(sql_query, engine)

# get user profile details
profile_df = pd.read_sql_query("select * from jos_user_profiles where profile_key in ('orgtype', 'organization', 'orcid')", engine)

# %%
# display
display(df.head(1))

display(profile_df.head(1))
# Out:
#     id             name username  block               email  sendEmail  \
# 0  998  hubrepo hubrepo  hubrepo      0  nkissebe@gmail.com          0
#
#          registerDate lastvisitDate
# 0 2014-11-13 21:09:09           NaT
#    id  user_id profile_key profile_value  ordering  access
# 0   1    15623     orgtype    university         2       5

# %%
df = pd.merge(df, profile_df[profile_df['profile_key'] == 'orgtype'][['user_id', 'profile_value']],\
                         how='left', left_on='id', right_on='user_id')\
    .drop(columns=['user_id']).rename(columns={'profile_value':'orgtype'})

df = pd.merge(df, profile_df[profile_df['profile_key'] == 'organization'][['user_id', 'profile_value']],\
                         how='left', left_on='id', right_on='user_id')\
    .drop(columns=['user_id']).rename(columns={'profile_value':'organization'})

df = pd.merge(df, profile_df[profile_df['profile_key'] == 'orcid'][['user_id', 'profile_value']],\
                         how='left', left_on='id', right_on='user_id')\
    .drop(columns=['user_id']).rename(columns={'profile_value':'orcid'})

# display
display(df.head(1))
# Out:
#     id             name username  block               email  sendEmail  \
# 0  998  hubrepo hubrepo  hubrepo      0  nkissebe@gmail.com          0
#
#          registerDate lastvisitDate orgtype organization orcid
# 0 2014-11-13 21:09:09           NaT     NaN          NaN   NaN

# %%
# Obtain company domain information from DB2
domain_df = pd.read_sql_query("select name as domain_name, domain, industry, `size range` as size, country \
from wang159_myrmekes.companies_email_domain", engine)

# %%
# make sure domain is unique and drop NaN
domain_df = domain_df.drop_duplicates(subset='domain', keep='first')

# %%
# get email domain of nanoHUB users
def get_domain(this_email):
    seg_list = this_email.split('@')
    
    if len(seg_list) == 2:
        return seg_list[1].lower()
    else:
        return None
    
df['email_host'] = df['email'].apply(get_domain)

# %% [markdown]
# ## Build interpretor for user-filled Organization

# %%
# given data
display(domain_df.head(2))
display(df.head(2))
# Out:
#           domain_name                domain  \
# 0   strategic interns  strategicinterns.com
# 1  bosque y comunidad  bosqueycomunidad.org
#
#                              industry  size country
# 0                education management  1-10   india
# 1  non-profit organization management  1-10   spain
#      id             name username  block                email  sendEmail  \
# 0   998  hubrepo hubrepo  hubrepo      0   nkissebe@gmail.com          0
# 1  1683  nanoHUB support  support      0  support@nanohub.org          0
#
#          registerDate       lastvisitDate     orgtype       organization  \
# 0 2014-11-13 21:09:09                 NaT         NaN                NaN
# 1 2008-11-19 22:51:04 2008-11-19 23:55:30  university  Purdue University
#
#   orcid   email_host
# 0   NaN    gmail.com
# 1   NaN  nanohub.org

# %%
# get domain by nanoHUB organization field
df['organization'] = df.organization.astype('str').apply(str.lower)

# %%
df.loc[(df['organization']=='nan'),'organization'] = None

# %% [markdown]
# ## Match using Jaccard Similarity

# %%
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
s_words = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/users/wang159/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re

def clean_domain(this_domain_name):
    
    if not this_domain_name:
        return None
    
    # Replace all non-alphanumeric characters with space
    this_domain_name = re.sub("[^0-9a-zA-Z]+", " ", this_domain_name.lower())
    name_list = this_domain_name.split(' ')
        
    # remove all stop words
    name_list = ['' if x in s_words else x for x in name_list]
    
    return set(filter(None, name_list))

# %%
# clean domain name
domain_df['domain_cleaned_set'] = domain_df.domain_name.apply(clean_domain)

# clean nanohub org name
df['org_cleaned_set'] = df.organization.apply(clean_domain)

# %%
# hash cleaned domain name
domain_df['domain_cleaned_hash'] = domain_df['domain_cleaned_set'].apply(lambda x: '-'.join(sorted(list(x))) if x else None)

# hash cleaned clean nanohub org name
df['org_cleaned_hash'] = df['org_cleaned_set'].apply(lambda x: '-'.join(sorted(list(x))) if x else None)

# %% [markdown]
# ## Collaborative filtering for commerical email hosts

# %%
df.head(2).T
# Out:
#                                     0                     1
# id                                998                  1683
# name                  hubrepo hubrepo       nanoHUB support
# username                      hubrepo               support
# block                               0                     0
# email              nkissebe@gmail.com   support@nanohub.org
# sendEmail                           0                     0
# registerDate      2014-11-13 21:09:09   2008-11-19 22:51:04
# lastvisitDate                     NaT   2008-11-19 23:55:30
# orgtype                           NaN            university
# organization                     None     purdue university
# orcid                             NaN                   NaN
# email_host                  gmail.com           nanohub.org
# org_cleaned_set                  None  {purdue, university}
# org_cleaned_hash                 None     purdue-university

# %%
def predict_if_commerical(this_email_host_df):
    # predict if this email host is commerical
    top_cnt = this_email_host_df['org_cleaned_hash'].value_counts()
    
    if top_cnt.shape[0] > 0:
        if (top_cnt.iloc[0]/top_cnt.sum()) < 0.2:
            return True
        else:
            return False
    
    else:
        return False
    
is_email_commerical = df[['email_host', 'org_cleaned_hash']].groupby('email_host').apply(predict_if_commerical)

# %%
# mark commerical email addresses
df = pd.merge(df, is_email_commerical.reset_index(name='is_email_commerical'),\
         how='left', left_on='email_host', right_on='email_host' ,)

# %%
# obtain domain estimation from email addresses
df = pd.merge(df, domain_df[~domain_df.domain.isin(is_email_commerical[is_email_commerical].index)]['domain'],\
         how='left', left_on='email_host', right_on='domain').rename(columns={'domain':'domain_by_email'})

# display
display(df.head(2).T)
# Out:
#                                        0                     1
# id                                   998                  1683
# name                     hubrepo hubrepo       nanoHUB support
# username                         hubrepo               support
# block                                  0                     0
# email                 nkissebe@gmail.com   support@nanohub.org
# sendEmail                              0                     0
# registerDate         2014-11-13 21:09:09   2008-11-19 22:51:04
# lastvisitDate                        NaT   2008-11-19 23:55:30
# orgtype                              NaN            university
# organization                        None     purdue university
# orcid                                NaN                   NaN
# email_host                     gmail.com           nanohub.org
# org_cleaned_set                     None  {purdue, university}
# org_cleaned_hash                    None     purdue-university
# is_email_commerical                 True                 False
# domain_by_email                      NaN           nanohub.org

# %% [markdown]
# ## Fuzzy derive organization from nanoHUB profiles

# %%
# attempt direct join by hash
domain_subset_df = domain_df[domain_df.domain.isin(df.email_host.unique())][['domain', 'domain_cleaned_hash']]
domain_subset_df = domain_subset_df[~domain_subset_df.domain.isna()&~domain_subset_df.domain_cleaned_hash.isna()]

derived_df = pd.merge(df, domain_subset_df.rename(columns={'domain':'domain_by_profile'}),\
         how='left', left_on='org_cleaned_hash', right_on='domain_cleaned_hash')\
        .drop('domain_cleaned_hash', axis=1)

# display
derived_df.sample(5).T
# Out:
#                                       42584                    170277  \
# id                                     45919                   202332
# name                          Hai Dang Trinh                 Simon Li
# username                        trinhhaidang                 simon777
# block                                      0                        0
# email                 trinhhaidang@gmail.com        1084510637@qq.com
# sendEmail                                  1                        1
# registerDate             2010-07-25 15:18:51      2018-07-04 02:03:30
# lastvisitDate            2010-07-26 02:31:44      2018-07-18 02:33:57
# orgtype              universityundergraduate  universityundergraduate
# organization                            None                     None
# orcid                                    NaN                      NaN
# email_host                         gmail.com                   qq.com
# org_cleaned_set                         None                     None
# org_cleaned_hash                        None                     None
# is_email_commerical                     True                     True
# domain_by_email                          NaN                      NaN
# domain_by_profile                        NaN                      NaN
#
#                                        169842                205287  \
# id                                     201786                270794
# name                            Eleicer Ching     Margaret W. Gitau
# username                       phstudiopanama                mgitau
# block                                       0                     0
# email                phstudiopanama@gmail.com     mgitau@purdue.edu
# sendEmail                                   0                     0
# registerDate              2018-06-25 21:58:51   2019-11-07 21:11:23
# lastvisitDate             2018-06-25 21:58:52                   NaT
# orgtype                     universityfaculty     universityfaculty
# organization                             None     purdue university
# orcid                                     NaN                   NaN
# email_host                          gmail.com            purdue.edu
# org_cleaned_set                          None  {purdue, university}
# org_cleaned_hash                         None     purdue-university
# is_email_commerical                      True                 False
# domain_by_email                           NaN            purdue.edu
# domain_by_profile                         NaN            purdue.edu
#
#                                    5930
# id                                   9355
# name                          Taik Semeli
# username                       taiksemeli
# block                                   0
# email                meckel2003@yahoo.com
# sendEmail                               0
# registerDate          2005-07-16 06:48:55
# lastvisitDate         2005-08-29 20:42:20
# orgtype                               NaN
# organization                         None
# orcid                                 NaN
# email_host                      yahoo.com
# org_cleaned_set                      None
# org_cleaned_hash                     None
# is_email_commerical                  True
# domain_by_email                       NaN
# domain_by_profile                     NaN

# %%
# attempt to reduce domain_df size to speedup Jaccard calculation
from itertools import chain

all_word_set = set(chain.from_iterable(derived_df[(derived_df['domain_by_profile'].isna() & (~derived_df['organization'].isna()))]\
                    .org_cleaned_set.values))

# select the domain_df entry with words from all_word_set
domain_subset_df = domain_df[domain_df.domain_cleaned_set.notnull()]
domain_subset_df = domain_subset_df[domain_subset_df.domain_cleaned_set\
                             .apply(lambda x: True if len(x.intersection(all_word_set)) > 0 else False)]

# %%
derived_subset_df
# Out:
#             id                       name    username  block  \
# 8         1690           Khaled M. Dadesh    k_dadesh      0
# 11        1693          tien thanh nguyen    tinguyen      0
# 13        1695           Richard Siergiej    siergiej      0
# 17        1699              Scott Howlett   jshowlett      0
# 18        1700               Marisa Bauza      marisa      0
# ...        ...                        ...         ...    ...
# 218426  287988                Jeff Scully   jscully86      0
# 218448  288017                 FotoQQ PKV      foto99      1
# 218483  288063             Darrin Clawson       dclaw      0
# 218596  288201        Reuben Costales Lim  reubenclim      0
# 218627  288243  Sachin Marotrao Shendokar    smshendo      0
#
#                             email  sendEmail        registerDate  \
# 8              k_dadesh@yahoo.com          0 2000-07-05 07:07:09
# 11      tien.t.nguye@jpl.nasa.gov          0 2000-09-06 03:12:13
# 13         siergiejrr@netzero.net          0 2000-09-15 22:04:53
# 17        scott_howlett@yahoo.com          0 2000-09-27 21:22:03
# 18              marisab@dc.uba.ar          0 2000-10-05 11:52:30
# ...                           ...        ...                 ...
# 218426        jscully86@gmail.com          1 2020-05-15 19:31:05
# 218448         eynmoney@gmail.com          0 2020-05-16 07:54:45
# 218483          d-claw@d-claw.com          1 2020-05-16 17:55:07
# 218596         reuben@wmsu.edu.ph          1 2020-05-18 14:39:05
# 218627   smshendo@aggies.ncat.edu          1 2020-05-18 22:32:34
#
#              lastvisitDate                  orgtype  \
# 8                      NaT                      NaN
# 11                     NaT                      NaN
# 13                     NaT                      NaN
# 17                     NaT                      NaN
# 18                     NaT                      NaN
# ...                    ...                      ...
# 218426 2020-05-16 14:53:23  universityundergraduate
# 218448 2020-05-16 07:55:46                    other
# 218483 2020-05-18 19:18:22                 industry
# 218596 2020-05-18 15:03:20               unemployed
# 218627 2020-05-18 22:32:34       universitygraduate
#
#                                              organization orcid  \
# 8                          centerfor solar energy studies   NaN
# 11                                                    jpl   NaN
# 13                                   bechtel bettis, inc.   NaN
# 17                                                cadence   NaN
# 18                            universidad de buenos aires   NaN
# ...                                                   ...   ...
# 218426                 university of missouri-kansas city   NaN
# 218448                                          pkv games   NaN
# 218483                                         individual   NaN
# 218596  philippine bioengineering & nanotechnology res...   NaN
# 218627  joint school of nanoscience and nanoengineerin...   NaN
#
#              email_host                                    org_cleaned_set  \
# 8             yahoo.com                {solar, centerfor, energy, studies}
# 11         jpl.nasa.gov                                              {jpl}
# 13          netzero.net                             {bechtel, inc, bettis}
# 17            yahoo.com                                          {cadence}
# 18            dc.uba.ar                   {universidad, buenos, aires, de}
# ...                 ...                                                ...
# 218426        gmail.com               {university, kansas, missouri, city}
# 218448        gmail.com                                       {games, pkv}
# 218483       d-claw.com                                       {individual}
# 218596      wmsu.edu.ph  {nanotechnology, incorporated, bioengineering,...
# 218627  aggies.ncat.edu  {nanoscience, school, carolina, nanoengineerin...
#
#                                          org_cleaned_hash is_email_commerical  \
# 8                          centerfor-energy-solar-studies                True
# 11                                                    jpl               False
# 13                                     bechtel-bettis-inc               False
# 17                                                cadence                True
# 18                            aires-buenos-de-universidad               False
# ...                                                   ...                 ...
# 218426                    city-kansas-missouri-university                True
# 218448                                          games-pkv                True
# 218483                                         individual               False
# 218596  bioengineering-incorporated-institute-nanotech...               False
# 218627  carolina-joint-nanoengineering-nanoscience-nor...               False
#
#        domain_by_email domain_by_profile
# 8                  NaN               NaN
# 11                 NaN               NaN
# 13         netzero.net               NaN
# 17                 NaN               NaN
# 18                 NaN               NaN
# ...                ...               ...
# 218426             NaN               NaN
# 218448             NaN               NaN
# 218483             NaN               NaN
# 218596     wmsu.edu.ph               NaN
# 218627             NaN               NaN
#
# [18369 rows x 17 columns]

# %%
def get_org(this_df):
    # look at the cohort with this label, do they have a commonly agreed domain_by_email? If so, use it
    this_dbe_count = this_df.domain_by_email.value_counts()

    if this_dbe_count.shape[0] < 1:
        return None

    this_top_dbe_perc = this_dbe_count.iloc[0]/this_dbe_count.sum()

    # if top choice occupies majority of cases, then this cohort can be implied to this domain_by_email address
    if this_top_dbe_perc > 0.5:
        return this_dbe_count.index[0] 


derived_hash = derived_subset_df.groupby('org_cleaned_hash').apply(get_org)

# %%
derived_df = pd.merge(derived_df, derived_hash.reset_index(name='domain_by_profile_infer'), how='left', left_on='org_cleaned_hash', right_on='org_cleaned_hash')

# %%
# display
derived_df.head(4).T
# Out:
#                                            0                     1  \
# id                                       998                  1683
# name                         hubrepo hubrepo       nanoHUB support
# username                             hubrepo               support
# block                                      0                     0
# email                     nkissebe@gmail.com   support@nanohub.org
# sendEmail                                  0                     0
# registerDate             2014-11-13 21:09:09   2008-11-19 22:51:04
# lastvisitDate                            NaT   2008-11-19 23:55:30
# orgtype                                  NaN            university
# organization                            None     purdue university
# orcid                                    NaN                   NaN
# email_host                         gmail.com           nanohub.org
# org_cleaned_set                         None  {purdue, university}
# org_cleaned_hash                        None     purdue-university
# is_email_commerical                     True                 False
# domain_by_email                          NaN           nanohub.org
# domain_by_profile                        NaN            purdue.edu
# domain_by_profile_infer                  NaN                   NaN
#
#                                             2                     3
# id                                       1684                  1685
# name                          Grid Statistics                   NCN
# username                             gridstat                   ncn
# block                                       0                     0
# email                    gridstat@nanohub.org       ncn@nanohub.org
# sendEmail                                   0                     0
# registerDate              2008-11-18 17:29:56   2008-11-11 19:17:04
# lastvisitDate             2020-02-14 18:50:14                   NaT
# orgtype                       universitystaff            university
# organization                purdue university     purdue university
# orcid                                     NaN                   NaN
# email_host                        nanohub.org           nanohub.org
# org_cleaned_set          {purdue, university}  {purdue, university}
# org_cleaned_hash            purdue-university     purdue-university
# is_email_commerical                     False                 False
# domain_by_email                   nanohub.org           nanohub.org
# domain_by_profile                  purdue.edu            purdue.edu
# domain_by_profile_infer                   NaN                   NaN

# %% [markdown]
# ## Relating user-filled organization from citation to standard table

# %%
# connect with DB2
import sqlalchemy as sql

# Citation authors
sql_query = "select * from jos_citations_authors"

authors_df = pd.read_sql_query(sql_query, engine)

# %%
authors_df.head(2)
# Out:
#        id       cid                    author  authorid  uidNumber  ordering  \
# 0  189134  10001576          Woody Gilbertson         0     100100         4
# 1  189135  10001576  Hesameddin Ilatikhameneh         0      42735         5
#
#     givenName middleName        surname       organization  ... ipCITY  \
# 0       Woody                Gilbertson  Purdue University  ...
# 1  Hesameddin             Ilatikhameneh  Purdue University  ...
#
#   ipLATITUDE ipLONGITUDE in_network orcid research_id gscholar_id scopus_id  \
# 0        NaN         NaN          0  None        None        None      None
# 1        NaN         NaN          0  None        None        None      None
#
#   researchgate_id notes
# 0            None  None
# 1            None  None
#
# [2 rows x 29 columns]

# %%
# replace N/A and empty values with None
authors_df.organization.replace('N/A', '', inplace=True)

# %%
# clean domain name
authors_df['domain_cleaned_set'] = authors_df.organization.apply(clean_domain)

# hash cleaned domain name
authors_df['domain_cleaned_hash'] = authors_df['domain_cleaned_set'].apply(lambda x: '-'.join(sorted(list(x))) if x else None)

# %%
# display
authors_df.head(4).T
# Out:
#                                         0                         1  \
# id                                 189134                    189135
# cid                              10001576                  10001576
# author                   Woody Gilbertson  Hesameddin Ilatikhameneh
# authorid                                0                         0
# uidNumber                          100100                     42735
# ordering                                4                         5
# givenName                           Woody                Hesameddin
# middleName
# surname                        Gilbertson             Ilatikhameneh
# organization            Purdue University         Purdue University
# org_dept
# orgtype
# countryresident
# email                  wgilber@purdue.edu     hesam_ilati@yahoo.com
# ip
# host
# countrySHORT
# countryLONG
# ipREGION
# ipCITY
# ipLATITUDE                            NaN                       NaN
# ipLONGITUDE                           NaN                       NaN
# in_network                              0                         0
# orcid                                None                      None
# research_id                          None                      None
# gscholar_id                          None                      None
# scopus_id                            None                      None
# researchgate_id                      None                      None
# notes                                None                      None
# domain_cleaned_set   {purdue, university}      {purdue, university}
# domain_cleaned_hash     purdue-university         purdue-university
#
#                                         2                         3
# id                                 189132                    189133
# cid                              10001576                  10001576
# author                     Daniel F Mejia             James Charles
# authorid                                0                         0
# uidNumber                           52349                     65635
# ordering                                2                         3
# givenName                          Daniel                     James
# middleName                              F
# surname                             Mejia                   Charles
# organization            Purdue University         Purdue University
# org_dept
# orgtype
# countryresident
# email                   denphi@denphi.com  charlejs.james@gmail.com
# ip
# host
# countrySHORT
# countryLONG
# ipREGION
# ipCITY
# ipLATITUDE                            NaN                       NaN
# ipLONGITUDE                           NaN                       NaN
# in_network                              0                         0
# orcid                                None                      None
# research_id                          None                      None
# gscholar_id                          None                      None
# scopus_id                            None                      None
# researchgate_id                      None                      None
# notes                                None                      None
# domain_cleaned_set   {purdue, university}      {purdue, university}
# domain_cleaned_hash     purdue-university         purdue-university

# %%
derived_df.head(1)
# Out:
#     id             name username  block               email  sendEmail  \
# 0  998  hubrepo hubrepo  hubrepo      0  nkissebe@gmail.com          0
#
#          registerDate lastvisitDate orgtype organization orcid email_host  \
# 0 2014-11-13 21:09:09           NaT     NaN         None   NaN  gmail.com
#
#   org_cleaned_set org_cleaned_hash is_email_commerical domain_by_email  \
# 0            None             None                True             NaN
#
#   domain_by_profile domain_by_profile_infer
# 0               NaN                     NaN

# %%
domain_subset_df.rename(columns={'domain_cleaned_hash':'domain_hash'})
# Out:
#                  domain                           domain_hash
# 8323      rocorange.com                   syracuse-university
# 9153          pu.edu.pk                     punjab-university
# 13875            vt.edu                         tech-virginia
# 17503          whoi.edu  hole-institution-oceanographic-woods
# 18451    washington.edu                 university-washington
# ...                 ...                                   ...
# 7091426          gsk.no                       glaxosmithkline
# 7093609    armleads.com                               arm-inc
# 7097593      ntu.edu.sg      nanyang-technological-university
# 7101385      furman.edu                     furman-university
# 7122758     kuleuven.be                             ku-leuven
#
# [852 rows x 2 columns]

# %%
#derived_df[derived_df.domain_cleaned_hash.isin(authors_df.domain_cleaned_hash.unique())]\
#                                        [['domain', 'domain_cleaned_hash']]

#derived_df[derived_df.domain_by_profile_infer.notnull()][['org_cleaned_hash', 'domain_by_profile_infer']]\
#    .rename(columns={'org_cleaned_hash':'domain_hash', 'domain_by_profile_infer':'domain'})\
#    .stack()

# get domain subset that contains domain_cleaned_hash in authors_df
domain_subset_df = domain_df[domain_df.domain_cleaned_hash.isin(authors_df.domain_cleaned_hash.unique())][['domain', 'domain_cleaned_hash']]
domain_subset_df = domain_subset_df[domain_subset_df.domain.notnull()&domain_subset_df.domain_cleaned_hash.notnull()]

domain_subset_all_df = pd.concat([derived_df[derived_df.domain_by_profile_infer.notnull()]\
                                                              [['org_cleaned_hash', 'domain_by_profile_infer']]\
                                                              .rename(columns={'org_cleaned_hash':'domain_hash', 'domain_by_profile_infer':'domain'})\
                                                        , domain_subset_df.rename(columns={'domain_cleaned_hash':'domain_hash'})]\
                                                        , sort=False).drop_duplicates()

# %%
# attempt direct join by hash
derived_authors_df = pd.merge(authors_df, domain_subset_all_df\
                              ,how='left', left_on='domain_cleaned_hash', right_on='domain_hash')\
                              .drop('domain_hash', axis=1)\
                              .rename(columns={'domain':'domain_by_citation'})

# display
derived_authors_df.sample(5).T
# Out:
#                                     4532                  15987  \
# id                                   8919              11771473
# cid                              10001085                     3
# author                    Changwook Jeong        M. Korkusinski
# authorid                                0                    10
# uidNumber                           19217                  8748
# ordering                                2                     1
# givenName                       Changwook                    M.
# middleName
# surname                             Jeong           Korkusinski
# organization            Purdue University     Purdue University
# org_dept                                                    N/A
# orgtype                                               Education
# countryresident                                              US
# email                                         marekk@purdue.edu
# ip                                                128.210.7.199
# host                                                 purdue.edu
# countrySHORT                                                 US
# countryLONG                                       UNITED STATES
# ipREGION                                                INDIANA
# ipCITY                                           WEST LAFAYETTE
# ipLATITUDE                            NaN                     0
# ipLONGITUDE                           NaN                     0
# in_network                              0                     1
# orcid                                None
# research_id                          None
# gscholar_id                          None
# scopus_id                            None                  None
# researchgate_id                      None                  None
# notes                                None                  None
# domain_cleaned_set   {purdue, university}  {purdue, university}
# domain_cleaned_hash     purdue-university     purdue-university
# domain_by_citation             purdue.edu            purdue.edu
#
#                                     3917                      5722   \
# id                                   8324                     10101
# cid                              10000955                  10001352
# author                  Mark S. Lundstrom              Khairul Alam
# authorid                                0                         0
# uidNumber                            2862                         0
# ordering                                3                         3
# givenName                            Mark                   Khairul
# middleName
# surname                         Lundstrom                      Alam
# organization            Purdue University  University of California
# org_dept
# orgtype
# countryresident
# email
# ip
# host
# countrySHORT
# countryLONG
# ipREGION
# ipCITY
# ipLATITUDE                            NaN                       NaN
# ipLONGITUDE                           NaN                       NaN
# in_network                              0                         0
# orcid                                None                      None
# research_id                          None                      None
# gscholar_id                          None                      None
# scopus_id                            None                      None
# researchgate_id                      None                      None
# notes                                None                      None
# domain_cleaned_set   {purdue, university}  {university, california}
# domain_cleaned_hash     purdue-university     california-university
# domain_by_citation             purdue.edu                  ucla.edu
#
#                                     6629
# id                                  11009
# cid                              10001533
# author                         Yaohua Tan
# authorid                                0
# uidNumber                               0
# ordering                                1
# givenName                          Yaohua
# middleName
# surname                               Tan
# organization            Purdue University
# org_dept
# orgtype
# countryresident
# email
# ip
# host
# countrySHORT
# countryLONG
# ipREGION
# ipCITY
# ipLATITUDE                            NaN
# ipLONGITUDE                           NaN
# in_network                              0
# orcid                                None
# research_id                          None
# gscholar_id                          None
# scopus_id                            None
# researchgate_id                      None
# notes                                None
# domain_cleaned_set   {purdue, university}
# domain_cleaned_hash     purdue-university
# domain_by_citation             purdue.edu

# %%
# rank the nanoHUB profile institutions that cannot be directly matched by occurance

derived_authors_subset_df = derived_authors_df[(derived_authors_df.domain_cleaned_hash.notnull() \
                                                                & derived_authors_df.domain_by_citation.isna())]

most_common_sets = derived_authors_subset_df.domain_cleaned_set.value_counts()

# display
most_common_sets.head(5)
# Out:
# {systems, raytheon}                                           103
# {systems, raytheon, ti}                                        88
# {instruments, incorporated, texas}                             63
# {university, engineering, technology, bangladesh}              45
# {purdue, university, sciences, microstructural, institute}     35
# Name: domain_cleaned_set, dtype: int64

# %%
# attempt to reduce domain_df size to speedup Jaccard calculation
from itertools import chain

all_word_set = set(chain.from_iterable(derived_authors_subset_df.domain_cleaned_set.values))

# select the domain_df entry with words from all_word_set
domain_subset_df = domain_df[domain_df.domain_cleaned_set.notnull()]
domain_subset_df = domain_subset_df[domain_subset_df.domain_cleaned_set\
                             .apply(lambda x: True if len(x.intersection(all_word_set)) > 0 else False)]

domain_subset_df = domain_subset_df[['domain_cleaned_set', 'domain']]

# %%
most_common_sets.head(5).index
# Out:
# Index([                                             {'systems', 'raytheon'},
#                                               {'systems', 'raytheon', 'ti'},
#                                    {'instruments', 'incorporated', 'texas'},
#                   {'university', 'engineering', 'technology', 'bangladesh'},
#        {'purdue', 'university', 'sciences', 'microstructural', 'institute'}],
#       dtype='object')

# %%
domain_subset_df
# Out:
#                                        domain_cleaned_set  \
# 3                                  {tws, technology, inc}
# 4                             {cardinal, llc, strategies}
# 5                     {ground, sports, limited, didsbury}
# 12                                    {f, rsat, koltu, u}
# 13                             {hong, kong, uil, limited}
# ...                                                   ...
# 7173418  {p, biuro, us, acowych, personelle, ug, kadrowo}
# 7173420                   {home, health, valley, eastern}
# 7173421                                               {p}
# 7173422       {comercio, de, industria, e, peixes, pesca}
# 7173423        {de, assessoria, viabily, cios, neg, ltda}
#
#                              domain
# 3                    talkwithsam.co
# 4           cardinal-strategies.com
# 5        didsburysportsground.co.uk
# 12                firsatkoltugu.com
# 13                    usived.com.br
# ...                             ...
# 7173418               personelle.pl
# 7173420            evhomehealth.com
# 7173421                  rmatus.com
# 7173422        sopescabrasil.com.br
# 7173423              viabily.com.br
#
# [2889819 rows x 2 columns]

# %%
def get_jaccard_score(a,b):
    
    if (not a) & (not b):
        return 0
    
    score = len(a.intersection(b))/len(a.union(b))
    
    return score


for this_set in most_common_sets.head(10).index:
    # calculate the Jaccard similarity
    max_index = domain_subset_df.domain_cleaned_set.apply(lambda x: get_jaccard_score(x, this_set)).idxmax()

    derived_authors_df.loc[derived_authors_df.domain_cleaned_set == this_set, 'domain_by_citation'] \
                = domain_subset_df.loc[max_index, 'domain']

# %%
derived_authors_df.sample(3).T
# Out:
#                                      2294  \
# id                                   6727
# cid                              10000512
# author                    Shaikh S. Ahmed
# authorid                                0
# uidNumber                            9293
# ordering                                7
# givenName                          Shaikh
# middleName
# surname                             Ahmed
# organization            Purdue University
# org_dept
# orgtype
# countryresident
# email
# ip
# host
# countrySHORT
# countryLONG
# ipREGION
# ipCITY
# ipLATITUDE                            NaN
# ipLONGITUDE                           NaN
# in_network                              0
# orcid                                None
# research_id                          None
# gscholar_id                          None
# scopus_id                            None
# researchgate_id                      None
# notes                                None
# domain_cleaned_set   {purdue, university}
# domain_cleaned_hash     purdue-university
# domain_by_citation             purdue.edu
#
#                                                                   8956  \
# id                                                            11777731
# cid                                                               2212
# author                                                    Samuel Reeve
# authorid                                                          6994
# uidNumber                                                        85981
# ordering                                                             0
# givenName                                                       Samuel
# middleName
# surname                                                          Reeve
# organization                                         Purdue University
# org_dept             School of Materials Engineering, Birck Nanotec...
# orgtype                                                      Education
# countryresident                                                     US
# email                                                sreeve@purdue.edu
# ip
# host
# countrySHORT
# countryLONG
# ipREGION
# ipCITY
# ipLATITUDE                                                           0
# ipLONGITUDE                                                          0
# in_network                                                           0
# orcid
# research_id
# gscholar_id
# scopus_id                                                         None
# researchgate_id                                                   None
# notes                                                             None
# domain_cleaned_set                                {purdue, university}
# domain_cleaned_hash                                  purdue-university
# domain_by_citation                                          purdue.edu
#
#                                                  6932
# id                                           11779578
# cid                                              2006
# author                                    Nitin Rathi
# authorid                                         5307
# uidNumber                                      124877
# ordering                                            2
# givenName                                       Nitin
# middleName
# surname                                         Rathi
# organization              University Of South Florida
# org_dept             Computer Science and Engineering
# orgtype                                     Education
# countryresident                                    US
# email                             nitinr@mail.usf.edu
# ip
# host
# countrySHORT
# countryLONG
# ipREGION
# ipCITY
# ipLATITUDE                                          0
# ipLONGITUDE                                         0
# in_network                                          0
# orcid
# research_id
# gscholar_id
# scopus_id                                        None
# researchgate_id                                  None
# notes                                            None
# domain_cleaned_set       {south, university, florida}
# domain_cleaned_hash          florida-south-university
# domain_by_citation                            usf.edu

# %% [markdown]
# ## Update citation information on Salesforce with domain information

# %%
from DB2SalesforceAPI import DB2SalesforceAPI

# create DB2 to Salesforce API object
db_s = DB2SalesforceAPI(sf_login_params)

# query the Salesforce IDs for contacts and citations. when updating junction objects, these IDs must be used

# get Salesforce ID for contacts
sf_cca_df = db_s.query_data('SELECT Id, nanoHUB_user_ID__c FROM contact_citation_asso__c where nanoHUB_user_ID__c != NULL')

sf_userID_df['nanoHUB_user_ID__c'] = sf_userID_df['nanoHUB_user_ID__c'].astype('int')
