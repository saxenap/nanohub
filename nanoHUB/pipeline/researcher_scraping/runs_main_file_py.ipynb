# %%
# %run main_file.py
# Out:
# Obtained Salesforce access token ...... True
# logging dir exists, you're good
# 2021-08-15 21:34:19,085| WARNING | /home/nanoHUB-user/venv/lib/python3.8/site-packages/IPython/utils/py3compat.py:168: DtypeWarning: Columns (3,5,10,12,13,14,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(compiler(f.read(), fname, 'exec'), glob, loc)
# 2021-08-15 21:34:19,085 - [WARNING] py.warnings [warnings._showwarnmsg:109]: /home/nanoHUB-user/venv/lib/python3.8/site-packages/IPython/utils/py3compat.py:168: DtypeWarning: Columns (3,5,10,12,13,14,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(compiler(f.read(), fname, 'exec'), glob, loc)
#    Active_duration__c                     Email Facebook_profile__c FirstName  \
# 0              7477.0       olschner@cremat.com                 NaN      Fred
# 1              7168.0  terje.finstad@fys.uio.no                 NaN     Terje
#
# ...
