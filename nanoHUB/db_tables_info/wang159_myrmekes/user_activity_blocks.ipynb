# %% [markdown]
# ##### Author: Praveen Saxena
# ##### Email: saxep01@gmail.com
# ##### Create Date: 7/24/2021
# ##### Purpose: Analyze the table _event_table_ in database _wang159_myrmekes_.

# %% [markdown]
# --------------------

# %% [markdown]
# # Input

# %%
database = 'wang159_myrmekes'
table = 'user_activity_blocks'

# %%
db_table = "%s.%s" % (database, table)
print(db_table)
# Out:
# wang159_myrmekes.user_activity_blocks

# %% [markdown]
# --------------------

# %% [markdown]
# # Preliminaries

# %%
# %%capture 

import pandas as pd
from pprint import pprint
from IPython.display import display, Markdown
import os

from nanoHUB.application import Application

application = Application.get_instance()
engine = application.new_db_engine(database)

# %% [markdown]
# --------------------

# %% [markdown]
# # Table Information

# %% [markdown]
# ## Table Indexes

# %%
sql = '''
SHOW INDEX FROM %s; 
'''

df = pd.read_sql(sql % db_table, engine)
display(df)
# Out:
#                   Table  Non_unique                       Key_name  \
# 0  user_activity_blocks           1  ix_user_activity_blocks_index
#
#    Seq_in_index Column_name Collation  Cardinality Sub_part Packed Null  \
# 0             1       index         A         1525     None   None  YES
#
#   Index_type Comment Index_comment
# 0      BTREE

# %% [markdown]
# ## Table Columns

# %%
sql = '''
SHOW FULL COLUMNS FROM %s;
'''
df = pd.read_sql(sql % db_table, engine)
display(df.head())
# Out:
#    Field        Type          Collation Null  Key Default Extra Privileges  \
# 0  index  bigint(20)               None  YES  MUL    None           select
# 1   user        text  latin1_swedish_ci  YES         None           select
# 2   tool        text  latin1_swedish_ci  YES         None           select
# 3  start    datetime               None  YES         None           select
# 4    end    datetime               None  YES         None           select
#
#   Comment
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# --------------------

# %% [markdown]
# # Data Information

# %% [markdown]
# ## Data Query

# %%
sql = '''
SELECT *
    FROM %s
LIMIT 100;
'''
df = pd.read_sql(sql % db_table, engine)

# %% [markdown]
# ## Data Info

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         100 non-null    int64
#  1   user          100 non-null    object
#  2   tool          100 non-null    object
#  3   start         100 non-null    datetime64[ns]
#  4   end           100 non-null    datetime64[ns]
#  5   ip            100 non-null    object
#  6   lon           100 non-null    float64
#  7   lat           100 non-null    float64
#  8   cluster       80 non-null     float64
#  9   scanned_date  100 non-null    datetime64[ns]
# dtypes: datetime64[ns](3), float64(3), int64(1), object(3)
# memory usage: 7.9+ KB
# None

# %% [markdown]
# ## Data Values

# %%
display(df.head())
display(df.tail())
# Out:
#    index         user          tool      start        end               ip  \
# 0      0  bafflerbach       jupyter 2020-04-11 2020-04-15    68.117.135.85
# 1      1     bsutton3          oof2 2020-04-08 2020-04-12     98.214.64.82
# 2      2     drkiraco          veda 2020-04-10 2020-04-16   208.102.33.153
# 3      3    erikzupa6   contactmaps 2020-04-12 2020-04-16  176.199.211.251
# 4      4       kguo34  ucb_compnano 2020-04-12 2020-04-16     174.63.7.166
#
#        lon      lat  cluster scanned_date
# 0 -89.5080  43.0736     12.0   2020-04-15
# 1 -89.6283  40.7122      3.0   2020-04-12
# 2 -84.4296  39.1390      NaN   1900-01-01
# 3   8.6865  50.1252      NaN   1900-01-01
# 4 -71.1282  42.2796      4.0   2020-04-16
#     index                   user            tool      start        end  \
# 95     95  veeramohanrao.mareedu           funuq 2020-04-10 2020-04-14
# 96     96  veeramohanrao.mareedu      fgmbuilder 2020-04-10 2020-04-14
# 97     97  veeramohanrao.mareedu       tellurium 2020-04-10 2020-04-14
# 98     98  veeramohanrao.mareedu  nanoplasticity 2020-04-10 2020-04-14
# 99     99               bullock8     matdatarepo 2020-04-11 2020-04-15
#
#                  ip      lon      lat  cluster scanned_date
# 95   157.44.252.159  78.4574  17.3846      NaN   1900-01-01
# 96   157.44.208.211  78.4574  17.3846      NaN   1900-01-01
# 97   157.44.208.211  78.4574  17.3846      NaN   1900-01-01
# 98   157.44.252.159  78.4574  17.3846      NaN   1900-01-01
# 99  128.211.186.107 -86.9147  40.4251      7.0   2020-04-15

# %% [markdown]
# ## Tools and Clusters

# %%
timeline_domains_df = df.groupby('tool')['cluster'].unique().reset_index()
pd.options.display.max_colwidth = 5000
display('Tools Used', timeline_domains_df['tool'].unique())
display(timeline_domains_df)
pd.reset_option('max_colwidth')
# Out:
# 'Tools Used'
# array(['1dhetero', 'adeptnpt', 'atcadlab', 'bandstrlab', 'bjt',
#        'cntbands-ext', 'cntfet', 'contactmaps', 'contourpv',
#        'crystal_viewer', 'cvgraph', 'dftmatprop', 'dftqe', 'dualfoil',
#        'echem', 'fettoy', 'fgmbuilder', 'fin', 'funuq', 'gprpiezo',
#        'gpuheompop', 'jupyter', 'jupyter60', 'matdatarepo', 'matsimtk',
#        'meep', 'moscntr', 'mosfetsat', 'mseml', 'msl', 'nacresimulator',
#        'nanomatmech', 'nanomos', 'nanoplasticity', 'nmst_dft',
#        'npassemblylab', 'oof2', 'padre', 'pc4covid19', 'pnjunctionlab',
#        'prolabox', 'pvlimits', 'pvpanelsim', 'reaxff597a', 's4sim',
#        'siesta', 'straincalc', 'tellurium', 'ucb_compnano', 'veda',
#        'vides', 'workspace'], dtype=object)
#               tool  \
# 0         1dhetero
# 1         adeptnpt
# 2         atcadlab
# 3       bandstrlab
# 4              bjt
# 5     cntbands-ext
# 6           cntfet
# 7      contactmaps
# 8        contourpv
# 9   crystal_viewer
# 10         cvgraph
# 11      dftmatprop
# 12           dftqe
# 13        dualfoil
# 14           echem
# 15          fettoy
# 16      fgmbuilder
# 17             fin
# 18           funuq
# 19        gprpiezo
# 20      gpuheompop
# 21         jupyter
# 22       jupyter60
# 23     matdatarepo
# 24        matsimtk
# 25            meep
# 26         moscntr
# 27       mosfetsat
# 28           mseml
# 29             msl
# 30  nacresimulator
# 31     nanomatmech
# 32         nanomos
# 33  nanoplasticity
# 34        nmst_dft
# 35   npassemblylab
# 36            oof2
# 37           padre
# 38      pc4covid19
# 39   pnjunctionlab
# 40        prolabox
# 41        pvlimits
# 42      pvpanelsim
# 43      reaxff597a
# 44           s4sim
# 45          siesta
# 46      straincalc
# 47       tellurium
# 48    ucb_compnano
# 49            veda
# 50           vides
# 51       workspace
#
#                                                            cluster
# 0                                                            [4.0]
# 1                                                            [0.0]
# 2                                                            [4.0]
# 3                                                            [3.0]
# 4                                                  [8.0, 3.0, 5.0]
# 5                                                            [4.0]
# 6                                                            [1.0]
# 7                                                            [nan]
# 8                                                            [0.0]
# 9                                                            [5.0]
# 10                                                           [nan]
# 11                                                           [0.0]
# 12                                          [1.0, 0.0, 14.0, 15.0]
# 13                                                           [nan]
# 14                                                           [nan]
# 15                                                           [0.0]
# 16                                                           [nan]
# 17                                                           [nan]
# 18                                                           [nan]
# 19                                                           [nan]
# 20                                                           [nan]
# 21                                          [12.0, 3.0, 11.0, 0.0]
# 22                                                           [nan]
# 23  [7.0, 1.0, 0.0, 26.0, 12.0, 14.0, 27.0, 11.0, 17.0, 5.0, 10.0]
# 24                                                           [6.0]
# 25                                                           [4.0]
# 26                                                           [nan]
# 27                                                      [8.0, 0.0]
# 28                                            [5.0, 4.0, 1.0, 2.0]
# 29                                                           [5.0]
# 30                                                           [nan]
# 31                                                           [0.0]
# 32                                                           [1.0]
# 33                                                           [nan]
# 34                                                      [0.0, 3.0]
# 35                                                           [0.0]
# 36                                           [3.0, 0.0, 9.0, 13.0]
# 37                                                           [3.0]
# 38                                                 [5.0, 6.0, 3.0]
# 39                                                          [17.0]
# 40                                                           [nan]
# 41                                                           [nan]
# 42                                                           [nan]
# 43                                                           [nan]
# 44                                                           [3.0]
# 45                                                           [4.0]
# 46                                                           [nan]
# 47                                                           [nan]
# 48                                                           [4.0]
# 49                                                           [nan]
# 50                                                           [3.0]
# 51                                                      [2.0, 0.0]

# %% [markdown]
# ## First & Last Points by DateTime

# %%
sorted_start_datetime_df = df.sort_values(by='start')

# %%
first = sorted_start_datetime_df.iloc[0]
first = pd.Series(first, name='First Data Point').to_frame()
display(first)

last = sorted_start_datetime_df.iloc[-1]
last = pd.Series(last, name='Last Data Point').to_frame()
display(last)
# Out:
#                  First Data Point
# index                          74
# user             medhoorumouni123
# tool                          fin
# start         2020-04-08 00:00:00
# end           2020-04-12 00:00:00
# ip                 223.238.35.110
# lon                       83.2016
# lat                       17.6801
# cluster                       NaN
# scanned_date  1900-01-01 00:00:00
#                   Last Data Point
# index                          84
# user           colewilloughby1125
# tool                  matdatarepo
# start         2020-04-12 00:00:00
# end           2020-04-16 00:00:00
# ip                 52.119.107.194
# lon                      -86.9256
# lat                       40.4444
# cluster                      10.0
# scanned_date  2020-04-16 00:00:00
